# %% [markdown]
# # Query data from overpassAPI (openstreetmaps)

# %% [markdown]
# query now with Python by using the requests package in order to access the Overpass AP

# %% [markdown]
# ## Area[] Berlin
# area["ISO3166-2"="DE-BE"]
# https://www.openstreetmap.org/relation/62422
#
# ## admin_level=4
# admin_level=2 through admin_level=10 allow for different administrative subdivision schemes to be handled in a consistent way by data consumers. The use of a numbering scheme rather than words for the values helps avoid confusion due to different terminology used in different countries
# A data consumer looking for municipalities corresponding to "city", "town" or "village" boundaries will find these tagged anywhere from admin_level=4 (e.g. relation Berlin)

# %%
from pathlib import Path  
import pandas as pd
import requests
import json
import csv

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-2"="DE-BE"][admin_level=4];
(node['shop'='convenience'](area);
 way['shop'='convenience' ](area);
 rel['shop'='convenience' ](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.58.1 bb9ccb2d',
#  'osm3s': {'timestamp_osm_base': '2022-06-01T10:37:29Z',
#   'timestamp_areas_base': '2022-06-01T10:16:09Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 63253672,
#    'lat': 52.4993218,
#    'lon': 13.2961178,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '39',
#     'addr:postcode': '10711',
#     'addr:street': 'Joachim-Friedrich-Straße',
#     'addr:suburb': 'Halensee',
#     'name': "Ku'damm Spätkauf & Kiosk",
#     'opening_hours': '24/7',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 141469102,
#    'lat': 52.5408415,
#    'lon': 13.1474707,
#    'tags': {'created_by': 'Potlatch 0.5d', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 253616592,
#    'lat': 52.5110467,
#    'lon': 13.4626981,
#    'tags': {'dog': 'no',
#     'name': 'Kauf Markt9',
#     'opening_hours': 'Mo-Fr 08:00-20:00; Sa 08:00-19:00',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 266629404,
#    'lat': 52.5092086,
#    'lon': 13.5874999,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '45',
#     'addr:postcode': '12621',
#     'addr:street': 'Mädewalder Weg',
#     'addr:suburb': 'Kaulsdorf',
#     'brand': 'Edeka',
#     'name': 'Nah und gut',
#     'opening_hours': 'Mo-Fr 07:00-19:00; Sa 07:00-13:00; PH off',
#     'operator': 'Heinz Vollack',
#     'phone': '+49305677706',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 269167454,
#    'lat': 52.4144951,
#    'lon': 13.4019812,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Esso',
#     'brand:wikidata': 'Q867662',
#     'brand:wikipedia': 'en:Esso',
#     'fuel:diesel': 'yes',
#     'fuel:e10': 'yes',
#     'fuel:lpg': 'yes',
#     'fuel:octane_95': 'yes',
#     'fuel:octane_98': 'yes',
#     'name': 'Esso',
#     'name:de': 'Esso',
#     'name:en': 'Esso',
#     'payment:dkv': 'yes',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 269475044,
#    'lat': 52.5017902,
#    'lon': 13.4165385,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '20',
#     'addr:postcode': '10999',
#     'addr:street': 'Dresdener Straße',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'fast_food',
#     'check_date:opening_hours': '2022-04-19',
#     'name': 'Milchladen',
#     'opening_hours': 'Mo-Fr 11:00-18:00; Su 13:00-18:00',
#     'organic': 'only',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 277681454,
#    'lat': 52.4990942,
#    'lon': 13.3931869,
#    'tags': {'name': 'Bagdad Lebensmittel',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 278124916,
#    'lat': 52.5083552,
#    'lon': 13.4529561,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '9',
#     'addr:postcode': '10245',
#     'addr:street': 'Revaler Straße',
#     'addr:suburb': 'Friedrichshain',
#     'entrance': 'yes',
#     'name': 'Drinks & more',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 282406641,
#    'lat': 52.5108993,
#    'lon': 13.4611651,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '14',
#     'addr:postcode': '10245',
#     'addr:street': 'Gärtnerstraße',
#     'addr:suburb': 'Friedrichshain',
#     'name': 'Drink Oase',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 286210165,
#    'lat': 52.4992044,
#    'lon': 13.4635638,
#    'tags': {'drink:club-mate': 'yes',
#     'name': 'Spätverkauf',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 287297820,
#    'lat': 52.5291171,
#    'lon': 13.4094976,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '188',
#     'addr:postcode': '10119',
#     'addr:street': 'Schönhauser Allee',
#     'name': 'Spätverkauf',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 298676294,
#    'lat': 52.5376931,
#    'lon': 13.2035603,
#    'tags': {'name': 'Reformhaus', 'shop': 'convenience', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 304897065,
#    'lat': 52.3934584,
#    'lon': 13.5726195,
#    'tags': {'name': 'Nhat Long', 'shop': 'convenience', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 310267641,
#    'lat': 52.4924848,
#    'lon': 13.4175963,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '55',
#     'addr:postcode': '10967',
#     'addr:street': 'Dieffenbachstraße',
#     'addr:suburb': 'Kreuzberg',
#     'name': 'E Markt',
#     'opening_hours': 'Mo-Sa 07:00-20:00',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 312820851,
#    'lat': 52.5429183,
#    'lon': 13.376473,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '78',
#     'addr:postcode': '13347',
#     'addr:street': 'Gerichtstraße',
#     'addr:suburb': 'Gesundbrunnen',
#     'amenity': 'post_office',
#     'name': 'Spätkauf',
#     'opening_hours': 'Mo-Fr 07:00-18:00; Sa 07:00-14:00',
#     'operator': 'DHL',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 313874489,
#    'lat': 52.5257591,
#    'lon': 13.4519646,
#    'tags': {'name': 'Asia Supermarket',
#     'opening_hours': 'Mo-Sa 10:00-23:00',
#     'origin': 'asian',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 313874493,
#    'lat': 52.5262878,
#    'lon': 13.4516579,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '52',
#     'addr:postcode': '10249',
#     'addr:street': 'Ebertystraße',
#     'addr:suburb': 'Friedrichshain',
#     'name': 'Eren',
#     'opening_hours': 'Mo-Sa 08:00-24:00',
#     'opening_hours:covid19': 'same',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 314401614,
#    'lat': 52.5231705,
#    'lon': 13.4531781,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '41',
#     'addr:postcode': '10249',
#     'addr:street': 'Straßmannstraße',
#     'addr:suburb': 'Friedrichshain',
#     'name': 'Asia Lebensmittel',
#     'opening_hours:covid19': 'open',
#     'opening_hours:signed': 'no',
#     'origin': 'asian',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 314401618,
#    'lat': 52.5227042,
#    'lon': 13.4513021,
#    'tags': {'name': 'Mini Markt 25',
#     'opening_hours': 'Mo-Sa 10:00-21:30',
#     'opening_hours:covid19': 'same',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 314401620,
#    'lat': 52.5223054,
#    'lon': 13.4509232,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '45',
#     'addr:postcode': '10249',
#     'addr:street': 'Petersburger Straße',
#     'addr:suburb': 'Friedrichshain',
#     'name': 'Ja Dilo',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 314401622,
#    'lat': 52.5231896,
#    'lon': 13.4503447,
#    'tags': {'name': 'Asia Shop',
#     'opening_hours:signed': 'no',
#     'origin': 'asian',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 322153511,
#    'lat': 52.5267897,
#    'lon': 13.3984785,
#    'tags': {'addr:housenumber': '39',
#     'addr:postcode': '10115',
#     'addr:street': 'Große Hamburger Straße',
#     'brand': 'Edeka',
#     'name': 'Kiezmarkt',
#     'opening_hours': 'Mo-Sa 08:00-22:00',
#     'operator': 'Kiezmarkt LH GmbH',
#     'phone': '+49 30 28388905',
#     'ref:vatin': 'DE3009207988',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 331347585,
#    'lat': 52.5087187,
#    'lon': 13.4616129,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '19',
#     'addr:postcode': '10245',
#     'addr:street': 'Wühlischstraße',
#     'addr:suburb': 'Friedrichshain',
#     'name': 'Nice 2 See U',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 364135228,
#    'lat': 52.4756969,
#    'lon': 13.4247724,
#    'tags': {'name': 'Orange', 'shop': 'convenience', 'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 411899540,
#    'lat': 52.5282633,
#    'lon': 13.3430149,
#    'tags': {'name': 'All in One Shop',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 420512359,
#    'lat': 52.4550699,
#    'lon': 13.375534,
#    'tags': {'name': 'Spätkauf am Atillaplatz',
#     'opening_hours': 'Mo-Th 06:00-00:00; Fr 06:00-01:00; Sa 10:00-00:30; Su 11:00-22:00',
#     'operator': 'Spätkauf',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 427670051,
#    'lat': 52.5120271,
#    'lon': 13.4964222,
#    'tags': {'name': 'Späti', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 427670062,
#    'lat': 52.5117432,
#    'lon': 13.4974878,
#    'tags': {'addr:housenumber': '246-248',
#     'addr:street': 'Frankfurter Allee',
#     'name': 'Kiez-Shop',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 429729075,
#    'lat': 52.4899925,
#    'lon': 13.3602113,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '160',
#     'addr:postcode': '10827',
#     'addr:street': 'Hauptstraße',
#     'addr:suburb': 'Schöneberg',
#     'name': 'Drinks Internetcafe Snacks',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 430126697,
#    'lat': 52.5028638,
#    'lon': 13.4543186,
#    'tags': {'drink:club-mate': 'yes',
#     'name': 'Obst und Gemüse',
#     'opening_hours': 'Mo-Su,PH 12:00-24:00',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 431655696,
#    'lat': 52.5097543,
#    'lon': 13.4622583,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '12',
#     'addr:postcode': '10245',
#     'addr:street': 'Seumestraße',
#     'addr:suburb': 'Friedrichshain',
#     'name': 'LPG',
#     'opening_hours': 'Mo-Fr 09:00-20:00; Sa 09:00-18:00',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 438150623,
#    'lat': 52.503197,
#    'lon': 13.4914514,
#    'tags': {'contact:fax': '+49 30 51068868',
#     'contact:phone': '+49 30 51068868',
#     'delivery:covid19': 'yes',
#     'name': 'Mini Markt',
#     'name:en': 'Mini Market',
#     'name:ru': 'Продуктовый магазин',
#     'opening_hours': 'Mo-Sa 07:00-20:30',
#     'opening_hours:covid19': 'Mo-Su 07:00-20:30',
#     'shop': 'convenience',
#     'takeaway:covid19': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 440971671,
#    'lat': 52.5510932,
#    'lon': 13.3564031,
#    'tags': {'name': 'Mini Market Alper',
#     'opening_hours': 'Mo-Sa 07:00-00:00',
#     'outdoor_seating': 'sidewalk',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 441513730,
#    'lat': 52.4609503,
#    'lon': 13.4346275,
#    'tags': {'name': 'Dost Markt', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 442749323,
#    'lat': 52.4673029,
#    'lon': 13.4403109,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '9',
#     'addr:postcode': '12051',
#     'addr:street': 'Silbersteinstraße',
#     'addr:suburb': 'Neukölln',
#     'name': 'Spät-Shop',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 446760653,
#    'lat': 52.4866393,
#    'lon': 13.3921451,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '17',
#     'addr:postcode': '10965',
#     'addr:street': 'Fidicinstraße',
#     'addr:suburb': 'Kreuzberg',
#     'description': 'Selected menswear and hand picked goods made in Germany',
#     'name': 'Simon & Me',
#     'phone': '+49 30 306 39 60 56',
#     'shop': 'convenience',
#     'website': 'https://simonandme.com/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 448594622,
#    'lat': 52.5011115,
#    'lon': 13.4410845,
#    'tags': {'name': 'Späti am Schlesi',
#     'outdoor_seating': 'sidewalk',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 452385593,
#    'lat': 52.5509168,
#    'lon': 13.5100245,
#    'tags': {'level': '0',
#     'name': 'Multi Spätkauf',
#     'opening_hours': 'Mo-Sa 07:00-01:00',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 454251024,
#    'lat': 52.4860909,
#    'lon': 13.4351467,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '54',
#     'addr:postcode': '12045',
#     'addr:street': 'Weichselstraße',
#     'addr:suburb': 'Neukölln',
#     'name': 'Spätcampus',
#     'opening_hours': '24/7',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 458138650,
#    'lat': 52.5211339,
#    'lon': 13.4465218,
#    'tags': {'name': 'Backwaren Spätkauf',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 461624503,
#    'lat': 52.5171097,
#    'lon': 13.4466536,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:postcode': '10243',
#     'addr:street': 'Karl-Marx-Allee',
#     'addr:suburb': 'Friedrichshain',
#     'check_date:opening_hours': '2022-02-10',
#     'name': 'Markt an der Weberwiese',
#     'opening_hours': 'Mo-Fr 08:00-20:00; Sa 08:00-18:00; Su 08:00-11:00',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 470319897,
#    'lat': 52.5885762,
#    'lon': 13.2855387,
#    'tags': {'name': 'Steinshop',
#     'shop': 'convenience',
#     'source': 'survey',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 476259949,
#    'lat': 52.4816447,
#    'lon': 13.4441313,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '9',
#     'addr:postcode': '12045',
#     'addr:street': 'Innstraße',
#     'addr:suburb': 'Neukölln',
#     'atm': 'no',
#     'atm:operator': 'Euronet',
#     'name': 'Heimgetränke',
#     'post_office:brand': 'DHL',
#     'post_office:type': 'post_partner',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 506197795,
#    'lat': 52.544033,
#    'lon': 13.4242868,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '50',
#     'addr:postcode': '10437',
#     'addr:street': 'Stargarder Straße',
#     'addr:suburb': 'Prenzlauer Berg',
#     'drink:club-mate': 'retail',
#     'name': 'Lateshop Café Roj',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 508657352,
#    'lat': 52.5880587,
#    'lon': 13.2849445,
#    'tags': {'shop': 'convenience', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 524769051,
#    'lat': 52.5891994,
#    'lon': 13.2805206,
#    'tags': {'name': 'Minimarkt',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 530715886,
#    'lat': 52.5417979,
#    'lon': 13.3575292,
#    'tags': {'name:signed': 'no', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 530715910,
#    'lat': 52.542862,
#    'lon': 13.3590534,
#    'tags': {'name': 'Spätkauf & Backwaren',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 560524658,
#    'lat': 52.5472275,
#    'lon': 13.4157637,
#    'tags': {'shop': 'convenience', 'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 560525457,
#    'lat': 52.5454075,
#    'lon': 13.4204087,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '21',
#     'addr:postcode': '10437',
#     'addr:street': 'Stargarder Straße',
#     'addr:suburb': 'Prenzlauer Berg',
#     'name': 'Verbrauchermarkt',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 567169596,
#    'lat': 52.5436171,
#    'lon': 13.416199,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:postcode': '10437',
#     'addr:street': 'Raumerstraße',
#     'addr:suburb': 'Prenzlauer Berg',
#     'name': 'RK Markt',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 567546833,
#    'lat': 52.5227373,
#    'lon': 13.4496607,
#    'tags': {'name': 'Petersburger Getränke Shop',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 567546844,
#    'lat': 52.523981,
#    'lon': 13.4527734,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '15',
#     'addr:postcode': '10249',
#     'addr:street': 'Ebertystraße',
#     'addr:suburb': 'Friedrichshain',
#     'name': 'Eberty Point',
#     'opening_hours:covid19': 'open',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 573381061,
#    'lat': 52.5128191,
#    'lon': 13.4673128,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '20',
#     'addr:postcode': '10247',
#     'addr:street': 'Scharnweberstraße',
#     'addr:suburb': 'Friedrichshain',
#     'name': 'Quang Loi',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 576051172,
#    'lat': 52.5129377,
#    'lon': 13.4658832,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:postcode': '10247',
#     'addr:street': 'Kinzigstraße',
#     'addr:suburb': 'Friedrichshain',
#     'name': 'Lebensmittel',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 576051178,
#    'lat': 52.514379,
#    'lon': 13.4659476,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '60',
#     'addr:postcode': '10247',
#     'addr:street': 'Frankfurter Allee',
#     'addr:suburb': 'Friedrichshain',
#     'name': 'Euro Spätkauf',
#     'opening_hours': '24/7',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 577380846,
#    'lat': 52.5461354,
#    'lon': 13.4180767,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:postcode': '10437',
#     'addr:street': 'Pappelallee',
#     'addr:suburb': 'Prenzlauer Berg',
#     'name': 'Papki',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 586663202,
#    'lat': 52.5132812,
#    'lon': 13.4713536,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 618020076,
#    'lat': 52.469814,
#    'lon': 13.4630769,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '4d',
#     'addr:postcode': '12057',
#     'addr:street': 'Grenzallee',
#     'amenity': 'post_office',
#     'drink:club-mate': 'yes',
#     'name': 'K Kiosk',
#     'opening_hours': 'Mo-Sa 07:00-19:00',
#     'shop': 'convenience',
#     'source': 'https://standorte.deutschepost.de/LocationDetail?template=locationdetail&standorttyp=filialen_verkaufspunkte&objecttype=branch&objectid=4121151',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 618021342,
#    'lat': 52.4682342,
#    'lon': 13.4672291,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 620704357,
#    'lat': 52.4825323,
#    'lon': 13.4409421,
#    'tags': {'shop': 'convenience', 'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 620704359,
#    'lat': 52.483436,
#    'lon': 13.4360938,
#    'tags': {'shop': 'convenience', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 626304112,
#    'lat': 52.5344555,
#    'lon': 13.4305661,
#    'tags': {'name': 'Corner',
#     'opening_hours': 'Mo-Th 08:00-24:00; Fr-Sa 08:00-01:00; Su 18:00-24:00',
#     'post_office:brand': 'DPD;GLS',
#     'post_office:type': 'post_partner',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 639566330,
#    'lat': 52.4933967,
#    'lon': 13.2958852,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '1',
#     'addr:postcode': '10711',
#     'addr:street': 'Joachim-Friedrich-Straße',
#     'addr:suburb': 'Halensee',
#     'name': 'Backshop & Kiosk',
#     'opening_hours': 'Mo-Fr 07:00-19:00; Sa 07:30-17:00',
#     'post_office': 'post_partner',
#     'post_office:brand': 'Hermes PaketShop',
#     'post_office:brand:wikidata': 'Q105702843',
#     'post_office:service_provider': 'Hermes Group',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 667858504,
#    'lat': 52.5033624,
#    'lon': 13.4121295,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '54',
#     'addr:postcode': '10969',
#     'addr:street': 'Oranienstraße',
#     'addr:suburb': 'Kreuzberg',
#     'name': 'Kiezkauf',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 678967934,
#    'lat': 52.5514691,
#    'lon': 13.3578197,
#    'tags': {'name': 'Bonbonwasser',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 697714204,
#    'lat': 52.5342305,
#    'lon': 13.4086992,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '17',
#     'addr:postcode': '10119',
#     'addr:street': 'Schwedter Straße',
#     'addr:suburb': 'Prenzlauer Berg',
#     'atm': 'yes',
#     'name': 'La Bodega',
#     'opening_hours': 'Mo-Su 12:00-24:00',
#     'payment:cash': 'yes',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 697907411,
#    'lat': 52.5488264,
#    'lon': 13.4140802,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '72c',
#     'addr:postcode': '10437',
#     'addr:street': 'Schönhauser Allee',
#     'addr:suburb': 'Prenzlauer Berg',
#     'name': 'Spätkauf -Late Shopping',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 700775299,
#    'lat': 52.5075231,
#    'lon': 13.4965878,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '40',
#     'addr:postcode': '10317',
#     'addr:street': 'Weitlingstraße',
#     'name': 'Weitling-Späti',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 703744109,
#    'lat': 52.4031371,
#    'lon': 13.5072516,
#    'tags': {'leisure': 'sports_centre', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 707353241,
#    'lat': 52.5508319,
#    'lon': 13.3787053,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '61',
#     'addr:postcode': '13357',
#     'addr:street': 'Pankstraße',
#     'name': 'Spätkauf Öztep',
#     'opening_hours': 'Mo-Sa 09:00-23:00',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 707452472,
#    'lat': 52.5463987,
#    'lon': 13.3696159,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '26',
#     'addr:postcode': '13347',
#     'addr:street': 'Reinickendorfer Straße',
#     'cafe': 'yes',
#     'level': '0',
#     'lottery': 'yes',
#     'name': 'Backwaren',
#     'opening_hours': 'Mo-Sa 06:00-19:00; Su 07:00-14:00',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 707490367,
#    'lat': 52.5522529,
#    'lon': 13.3821551,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '25',
#     'addr:postcode': '13357',
#     'addr:street': 'Badstraße',
#     'addr:suburb': 'Gesundbrunnen',
#     'name': 'Kiosk',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 736620808,
#    'lat': 52.4746659,
#    'lon': 13.4232927,
#    'tags': {'name': 'Kiezladen', 'shop': 'convenience', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 736787803,
#    'lat': 52.5278285,
#    'lon': 13.4101407,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '45',
#     'addr:postcode': '10178',
#     'addr:street': 'Rosa-Luxemburg-Straße',
#     'addr:suburb': 'Mitte',
#     'name': 'Pi pa po',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 745733025,
#    'lat': 52.4879348,
#    'lon': 13.430489,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '205',
#     'addr:postcode': '12047',
#     'addr:street': 'Weserstraße',
#     'addr:suburb': 'Neukölln',
#     'name': 'small all',
#     'opening_hours': 'Mo-Sa 06:30-24:00',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 746478626,
#    'lat': 52.4875623,
#    'lon': 13.4375216,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '30',
#     'addr:postcode': '12045',
#     'addr:street': 'Weichselstraße',
#     'addr:suburb': 'Neukölln',
#     'check_date': '2020-12-14',
#     'name': 'Honigbienchen Späti & Bakery',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 746853061,
#    'lat': 52.5802548,
#    'lon': 13.3988194,
#    'tags': {'amenity': 'bar',
#     'internet_access': 'terminal',
#     'name': 'Babylon Café Bar',
#     'service:phone': 'yes',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 747845608,
#    'lat': 52.4553748,
#    'lon': 13.5765726,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '49',
#     'addr:postcode': '12555',
#     'addr:street': 'Bahnhofstraße',
#     'addr:suburb': 'Köpenick',
#     'drink:club-mate': 'retail',
#     'name': 'Café Kiez',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 753361458,
#    'lat': 52.5704399,
#    'lon': 13.410203,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '1',
#     'addr:postcode': '13187',
#     'addr:street': 'Berliner Straße',
#     'addr:suburb': 'Pankow',
#     'name': 'Flick Flack',
#     'opening_hours': '24/7',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 769270131,
#    'lat': 52.5745998,
#    'lon': 13.357608,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '6',
#     'addr:postcode': '13407',
#     'addr:street': 'Alt-Reinickendorf',
#     'addr:suburb': 'Reinickendorf',
#     'check_date:opening_hours': '2021-10-25',
#     'name': 'Naturkost',
#     'opening_hours': 'Mo-Fr 09:00-18:00; Sa 09:00-13:30',
#     'organic': 'only',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 769849999,
#    'lat': 52.5663982,
#    'lon': 13.3632929,
#    'tags': {'name': "Resi's Spät Shop", 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 778710944,
#    'lat': 52.5374494,
#    'lon': 13.408254,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '26',
#     'addr:postcode': '10435',
#     'addr:street': 'Kastanienallee',
#     'addr:suburb': 'Prenzlauer Berg',
#     'name': 'Spätkauf',
#     'opening_hours': 'Mo-Th 09:00-23:00, Su 10:00-24:00; Fr 09:00-24:00',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 778710967,
#    'lat': 52.5401664,
#    'lon': 13.4111403,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '5',
#     'addr:postcode': '10435',
#     'addr:street': 'Kastanienallee',
#     'addr:suburb': 'Prenzlauer Berg',
#     'contact:phone': '+49-177-7198831',
#     'cuisine': 'turkish',
#     'name': "Polat's Minimarkt",
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 779158279,
#    'lat': 52.488513,
#    'lon': 13.3532962,
#    'tags': {'check_date:opening_hours': '2022-04-22',
#     'name': 'Ährensache',
#     'opening_hours': 'Mo-Fr 07:30-19:00; Sa 07:30-13:30',
#     'organic': 'only',
#     'shop': 'convenience',
#     'website': 'https://www.aehrensache-berlin.de/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 838429741,
#    'lat': 52.506133,
#    'lon': 13.4655484,
#    'tags': {'name': 'Käptn Kiez',
#     'opening_hours': 'Mo 09:00-24:00; Tu-Th 00:00-02:00,09:00-24:00; Fr 00:00-02:00,10:00-24:00; Sa 00:00-04:00,10:00-24:00; Su 00:00-04:00',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 838429759,
#    'lat': 52.5049744,
#    'lon': 13.4674633,
#    'tags': {'name': 'Kiosk 24',
#     'opening_hours': '24/7',
#     'shop': 'convenience',
#     'type': 'kiosk',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 838429794,
#    'lat': 52.5046457,
#    'lon': 13.4678618,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '2',
#     'addr:postcode': '10245',
#     'addr:street': 'Sonntagstraße',
#     'addr:suburb': 'Friedrichshain',
#     'name': 'Die Späti Brüder',
#     'shop': 'convenience',
#     'type': 'kiosk',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 847907650,
#    'lat': 52.4669419,
#    'lon': 13.5133836,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:postcode': '12459',
#     'addr:street': 'Edisonstraße',
#     'cuisine': 'asian',
#     'name': 'Spätkauf 63',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 848169211,
#    'lat': 52.4668756,
#    'lon': 13.3198096,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '7',
#     'addr:postcode': '14197',
#     'addr:street': 'Kreuznacher Straße',
#     'name': 'Kreuznacher Markt',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 861837755,
#    'lat': 52.4575426,
#    'lon': 13.3843486,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '207',
#     'addr:postcode': '12099',
#     'addr:street': 'Tempelhofer Damm',
#     'addr:suburb': 'Tempelhof',
#     'name': 'Karam Al-Sham',
#     'opening_hours': 'Mo-Fr 08:30-20:00; Sa 08:30-19:00',
#     'origin': 'lebanese',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 863962594,
#    'lat': 52.5058829,
#    'lon': 13.4703076,
#    'tags': {'name': 'Kiez Shop',
#     'opening_hours:signed': 'no',
#     'post_box': 'yes',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 863962795,
#    'lat': 52.5072131,
#    'lon': 13.4684572,
#    'tags': {'addr:city': 'Berlin',
#     'addr:street': 'Boxhagener Straße',
#     'name': 'Boxi Spätshop',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 867497539,
#    'lat': 52.5255327,
#    'lon': 13.3303661,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '30',
#     'addr:postcode': '10555',
#     'addr:street': 'Gotzkowskystraße',
#     'addr:suburb': 'Moabit',
#     'name': 'Pamuk Shop',
#     'opening_hours': 'Mo-Sa 12:00-01:00',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 867497554,
#    'lat': 52.52558,
#    'lon': 13.3299243,
#    'tags': {'name': 'Habibi', 'shop': 'convenience', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 867848037,
#    'lat': 52.499861,
#    'lon': 13.4191728,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '4',
#     'addr:postcode': '10999',
#     'addr:street': 'Adalbertstraße',
#     'addr:suburb': 'Kreuzberg',
#     'contact:email': 's.tosun@36boys.com',
#     'contact:phone': '+49 30 83 03 94 33',
#     'contact:website': 'http://36boys.com/',
#     'name': '36boys',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 885998522,
#    'lat': 52.4996809,
#    'lon': 13.4297459,
#    'tags': {'name': 'Quicky Markt',
#     'opening_hours': 'Mo-Fr 10:00-23:00; Sa 13:00-23:00',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 886089002,
#    'lat': 52.4982621,
#    'lon': 13.4288645,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '14',
#     'addr:postcode': '10999',
#     'addr:street': 'Wiener Straße',
#     'addr:suburb': 'Kreuzberg',
#     'name': 'Checkpoint Ali',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 886154881,
#    'lat': 52.4987819,
#    'lon': 13.4273375,
#    'tags': {'name:signed': 'no', 'shop': 'convenience', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 920664308,
#    'lat': 52.4981816,
#    'lon': 13.3848148,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '11',
#     'addr:postcode': '10963',
#     'addr:street': 'Großbeerenstraße',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'cafe',
#     'contact:email': 'info@oekotussi.de',
#     'contact:phone': '+49 30 54859301',
#     'contact:website': 'http://www.oekotussi.de',
#     'delivery:covid19': 'yes',
#     'diet:vegan': 'yes',
#     'name': 'Ökotussi',
#     'opening_hours': 'Mo-Fr 07:00-18:00; Sa 09:00-14:00; PH off',
#     'opening_hours:covid19': 'Mo-Fr 07:00-18:00; Sa 09:00-14:00',
#     'organic': 'yes',
#     'shop': 'convenience',
#     'takeaway:covid19': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 939667428,
#    'lat': 52.5414875,
#    'lon': 13.3487169,
#    'tags': {'name': 'Late Shop am Virchow',
#     'opening_hours': 'Mo-Sa 09:00-24:00',
#     'phone': '+49 30 45977275',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 939667458,
#    'lat': 52.5416669,
#    'lon': 13.3494233,
#    'tags': {'name': 'Media Point',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 947301033,
#    'lat': 52.5533409,
#    'lon': 13.4083302,
#    'tags': {'name': 'Lebensmittel und Getränke',
#     'opening_hours': 'Mo-Fr 09:30-22:00; Sa 10:30-22:00',
#     'shop': 'convenience',
#     'source': 'survey',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 988401415,
#    'lat': 52.445943,
#    'lon': 13.500479,
#    'tags': {'name': 'Mini-Markt',
#     'phone': '+49 30 6311067',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 991750714,
#    'lat': 52.4938895,
#    'lon': 13.4218188,
#    'tags': {'name': 'latenight shop',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1003885734,
#    'lat': 52.5272929,
#    'lon': 13.4500121,
#    'tags': {'name': 'Panorama Spätkauf',
#     'shop': 'convenience',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1028138858,
#    'lat': 52.4885157,
#    'lon': 13.4287783,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '56',
#     'addr:postcode': '12047',
#     'addr:street': 'Reuterstraße',
#     'name': 'Backshop Tabak&Presse',
#     'outdoor_seating': 'yes;sidewalk',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1085324528,
#    'lat': 52.5469121,
#    'lon': 13.406241,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '11',
#     'addr:postcode': '10437',
#     'addr:street': 'Gleimstraße',
#     'check_date:opening_hours': '2020-11-18',
#     'description': 'Späti DHL Paketshop Amazon Locker "nela"',
#     'name': 'Mauermarkt',
#     'opening_hours': 'Mo-Su 08:00-24:00',
#     'operator': 'Renee Maeser',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1092250109,
#    'lat': 52.5154783,
#    'lon': 13.290879,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '52',
#     'addr:postcode': '14059',
#     'addr:street': 'Danckelmannstraße',
#     'addr:suburb': 'Charlottenburg',
#     'name': 'Kiezmarkt mediterrane Welt',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1095435039,
#    'lat': 52.5402467,
#    'lon': 13.4158448,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '20',
#     'addr:postcode': '10435',
#     'addr:street': 'Danziger Straße',
#     'addr:suburb': 'Prenzlauer Berg',
#     'name': 'Asia Mini Shop',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1100350416,
#    'lat': 52.5394809,
#    'lon': 13.4238961,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '71',
#     'addr:postcode': '10435',
#     'addr:street': 'Danziger Straße',
#     'addr:suburb': 'Prenzlauer Berg',
#     'drink:club-mate': 'retail',
#     'name': 'Danziger Express',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1109675825,
#    'lat': 52.4854176,
#    'lon': 13.4268834,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '15',
#     'addr:postcode': '12043',
#     'addr:street': 'Karl-Marx-Straße',
#     'addr:suburb': 'Neukölln',
#     'check_date:opening_hours': '2020-09-27',
#     'contact:phone': '+49 30 63413016',
#     'name': 'Asien Supermarkt Hao Cai Lei',
#     'name:en': 'Asia Supermarket Hao Chai Lei',
#     'name:zh': '好又多',
#     'opening_hours': 'Mo-Sa 10:00-19:30',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1110086631,
#    'lat': 52.5053204,
#    'lon': 13.3940873,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '68',
#     'addr:postcode': '10969',
#     'addr:street': 'Markgrafenstraße',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'restaurant',
#     'email': 'info@superiberico.de',
#     'fax': '+49 30 35123929',
#     'name': 'Super Ibérico',
#     'opening_hours': 'Mo-Fr 09:00-19:00; Sa 10:00-17:00',
#     'phone': '+49 30 35123931',
#     'shop': 'convenience',
#     'website': 'http://www.superiberico.de'}},
#   {'type': 'node',
#    'id': 1116716789,
#    'lat': 52.5348523,
#    'lon': 13.4379797,
#    'tags': {'name': 'Lebensmittel',
#     'opening_hours': 'Mo-Sa 09:00-23:00',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1140906805,
#    'lat': 52.5065512,
#    'lon': 13.4698185,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '69',
#     'addr:postcode': '10245',
#     'addr:street': 'Neue Bahnhofstraße',
#     'addr:suburb': 'Friedrichshain',
#     'name': 'Ellîka Spätkauf',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1140914372,
#    'lat': 52.5100286,
#    'lon': 13.462105,
#    'tags': {'name': 'City Kiosk',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1140926746,
#    'lat': 52.5157165,
#    'lon': 13.4399122,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '31',
#     'addr:postcode': '10243',
#     'addr:street': 'Straße der Pariser Kommune',
#     'name': 'K Mini Markt',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1140927943,
#    'lat': 52.5110245,
#    'lon': 13.4356582,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '6',
#     'addr:postcode': '10243',
#     'addr:street': 'Erich-Steinfurth-Straße',
#     'addr:suburb': 'Friedrichshain',
#     'name': 'Spätkauf am Ostbahnhof',
#     'opening_hours': '24/7',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1140928753,
#    'lat': 52.5230609,
#    'lon': 13.4344701,
#    'tags': {'name': 'Spätkauf Lebensmittel',
#     'shop': 'convenience',
#     'survey:date': '2016-10-08',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1140930611,
#    'lat': 52.519883,
#    'lon': 13.4516496,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housename': 'Nebenan Markt',
#     'addr:housenumber': '68',
#     'addr:postcode': '10249',
#     'addr:street': 'Petersburger Straße',
#     'addr:suburb': 'Friedrichshain',
#     'name': 'Spätshop 68',
#     'opening_hours': '09:00-24:00',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1140935486,
#    'lat': 52.5222261,
#    'lon': 13.449453,
#    'tags': {'name': 'Para Spätkauf',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1161375510,
#    'lat': 52.5534498,
#    'lon': 13.3921872,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '24',
#     'addr:postcode': '13357',
#     'addr:street': 'Jülicher Straße',
#     'name': 'Aksu Kiosk',
#     'note': 'Späti',
#     'opening_hours': '24/7',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1166648844,
#    'lat': 52.4369217,
#    'lon': 13.7181357,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 1172023257,
#    'lat': 52.6069342,
#    'lon': 13.4217062,
#    'tags': {'name': 'Wohnung Werkstatt Garten Shop',
#     'shop': 'convenience',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1181625810,
#    'lat': 52.5091058,
#    'lon': 13.4555933,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '18',
#     'addr:postcode': '10245',
#     'addr:street': 'Simon-Dach-Straße',
#     'addr:suburb': 'Friedrichshain',
#     'atm': 'yes',
#     'entrance': 'yes',
#     'name': 'Esperanto',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1203807178,
#    'lat': 52.5116257,
#    'lon': 13.3898386,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '63',
#     'addr:postcode': '10117',
#     'addr:street': 'Friedrichstraße',
#     'addr:suburb': 'Mitte',
#     'diet:vegan': 'yes',
#     'diet:vegetarian': 'yes',
#     'name': 'Superfoods & Organic Liquids',
#     'outdoor_seating': 'yes',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1212618126,
#    'lat': 52.4799667,
#    'lon': 13.5214915,
#    'tags': {'name': "Müller's",
#     'opening_hours': 'Mo-Fr 07:00-20:00; Sa 07:00-18:00',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1221375859,
#    'lat': 52.5087859,
#    'lon': 13.4973357,
#    'tags': {'internet_access': 'yes',
#     'name': 'Sipan Spätverkauf',
#     'opening_hours': 'Mo-Fr 01:00-24:00, Sa 01:00-24:00',
#     'service:phone': 'yes',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1225127392,
#    'lat': 52.5196117,
#    'lon': 13.1712485,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '66',
#     'addr:postcode': '13593',
#     'addr:street': 'Sandstraße',
#     'name': "Mia's Späti",
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 1251129216,
#    'lat': 52.5375585,
#    'lon': 13.4111971,
#    'tags': {'name': 'Spätkauf', 'shop': 'convenience', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1255588542,
#    'lat': 52.4923613,
#    'lon': 13.4169147,
#    'tags': {'name': 'kinzi discount',
#     'opening_hours': 'Mo-Fr 08:00-22:00; Sa 09:00-22:00',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1258615840,
#    'lat': 52.5237092,
#    'lon': 13.4393122,
#    'tags': {'name': 'Spätshop', 'note': 'Spätkauf 38', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 1259381388,
#    'lat': 52.5014008,
#    'lon': 13.4934074,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '117',
#     'addr:postcode': '10317',
#     'addr:street': 'Weitlingstraße',
#     'check_date:opening_hours': '2020-12-15',
#     'contact:mobile': '+49 173 4702537',
#     'name': 'Minimarkt Mura',
#     'opening_hours': 'Mo-Fr 07:00-23:00; Sa,Su,PH 08:00-23:00',
#     'operator': 'Thi Hanh Mura',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1262166743,
#    'lat': 52.4568134,
#    'lon': 13.384211,
#    'tags': {'name': '24 H Shop',
#     'opening_hours': 'Mo-Sa 00:00-24:00',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1269798909,
#    'lat': 52.5541616,
#    'lon': 13.3397118,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '21',
#     'addr:postcode': '13351',
#     'addr:street': 'Otawistraße',
#     'addr:suburb': 'Wedding',
#     'level': '0',
#     'name': 'Kiosk 21',
#     'shop': 'convenience',
#     'toilets:wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1274104691,
#    'lat': 52.5211006,
#    'lon': 13.4470268,
#    'tags': {'name': 'Schmidt´s Laden',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1293209218,
#    'lat': 52.5143319,
#    'lon': 13.4929949,
#    'tags': {'name': 'Minimarkt',
#     'opening_hours': 'Mo-Fr 08:00-20:00; Sa 08:00-19:00',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1294929416,
#    'lat': 52.5258885,
#    'lon': 13.3070269,
#    'tags': {'addr:city': 'Berlin',
#     'addr:postcode': '10589',
#     'addr:street': 'Kaiserin-Augusta-Allee',
#     'name': '@y mierendorff net',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 1305230438,
#    'lat': 52.518017,
#    'lon': 13.3168638,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '36',
#     'addr:postcode': '10587',
#     'addr:street': 'Guerickestraße',
#     'addr:suburb': 'Charlottenburg',
#     'name': 'Sultan Shop',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 1307115292,
#    'lat': 52.4687842,
#    'lon': 13.4302906,
#    'tags': {'name': 'Sarikiz Spätkauf 44',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1311121901,
#    'lat': 52.5062656,
#    'lon': 13.3113681,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '124',
#     'addr:postcode': '10625',
#     'addr:street': 'Kantstraße',
#     'addr:suburb': 'Charlottenburg',
#     'name': 'Iran Shop',
#     'opening_hours': 'Mo-Sa 10:00-19:00',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1312144101,
#    'lat': 52.5094123,
#    'lon': 13.3916066,
#    'tags': {'name': 'Ecity',
#     'opening_hours': 'Mo-Fr 08:00-23:00; Sa 10:00-23:00',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1313284328,
#    'lat': 52.5546103,
#    'lon': 13.4153894,
#    'tags': {'check_date:opening_hours': '2022-03-05',
#     'name': 'neon Spätkauf',
#     'opening_hours': 'Mo-Sa 10:00-24:00',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1315201887,
#    'lat': 52.489136,
#    'lon': 13.4509862,
#    'tags': {'name': 'Global Kontakt',
#     'opening_hours': 'Mo-Sa 09:00-23:00',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1320138052,
#    'lat': 52.4980049,
#    'lon': 13.4211603,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '26',
#     'addr:postcode': '10999',
#     'addr:street': 'Reichenberger Straße',
#     'addr:suburb': 'Kreuzberg',
#     'check_date': '2021-08-16',
#     'name': 'Eis Mari',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1324860212,
#    'lat': 52.4591429,
#    'lon': 13.5253076,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:postcode': '12459',
#     'check_date:opening_hours': '2022-03-06',
#     'name': 'Spätkauf',
#     'opening_hours': '08:00-24:00',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1332197461,
#    'lat': 52.47496,
#    'lon': 13.3428619,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '28',
#     'addr:postcode': '12159',
#     'addr:street': 'Rubensstraße',
#     'addr:suburb': 'Schöneberg',
#     'dry_cleaning': 'yes',
#     'ice_cream': 'yes',
#     'noname': 'yes',
#     'note': 'das Hauptschild weist aus: "Tabakwaren-Getränke / Zeitungen und Zeitschriften" -> ein genauer Name ist nicht ersichtlich',
#     'opening_hours': 'Mo-Fr 06:00-19:00; Sa 07:00-16:00; Su 07:30-14:00',
#     'shop': 'convenience',
#     'tobacco': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1344436749,
#    'lat': 52.475761,
#    'lon': 13.339905,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '11',
#     'addr:postcode': '12159',
#     'addr:street': 'Hähnelstraße',
#     'addr:suburb': 'Friedenau',
#     'opening_hours': 'Mo-Sa 08:00-24:00',
#     'post_office': 'post_partner',
#     'post_office:brand': 'Hermes PaketShop;DPD;UPS Access Point',
#     'post_office:brand:wikidata': 'Q105702843',
#     'post_office:service_provider': 'Hermes Group;DPD;UPS',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1345222866,
#    'lat': 52.5006355,
#    'lon': 13.4316495,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '11',
#     'addr:postcode': '10997',
#     'addr:street': 'Lausitzer Platz',
#     'addr:suburb': 'Kreuzberg',
#     'noname': 'yes',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1346939681,
#    'lat': 52.5069169,
#    'lon': 13.4234636,
#    'tags': {'name': 'Mini Markt',
#     'opening_hours': 'Mo-Fr 06:00-02:00, Sa 06:00-03:00',
#     'shop': 'convenience',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1346939765,
#    'lat': 52.5029232,
#    'lon': 13.4202891,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '80',
#     'addr:postcode': '10997',
#     'addr:street': 'Adalbertstraße',
#     'addr:suburb': 'Kreuzberg',
# ...
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 8766255543,
#    'lat': 52.4199942,
#    'lon': 13.5785091,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '89',
#     'addr:postcode': '12527',
#     'addr:street': 'Regattastraße',
#     'name': 'Tuans Späti',
#     'opening_hours': 'Mo-Fr 07:00-23:00, Sa 10:00-23:00',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 8775512439,
#    'lat': 52.485462,
#    'lon': 13.4258668,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '12',
#     'addr:postcode': '12043',
#     'addr:street': 'Karl-Marx-Straße',
#     'check_date': '2021-05-28',
#     'name': 'Oriental Shop',
#     'opening_hours': 'Mo 09:00-20:00; Tu-Sa 10:00-19:00',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 8775512441,
#    'lat': 52.4854094,
#    'lon': 13.4259762,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '12',
#     'addr:postcode': '12043',
#     'addr:street': 'Karl-Marx-Straße',
#     'check_date': '2021-05-28',
#     'name': 'Marx shop 12',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 8783823473,
#    'lat': 52.5153286,
#    'lon': 13.4715926,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '57',
#     'addr:postcode': '10247',
#     'addr:street': 'Rigaer Straße',
#     'addr:suburb': 'Friedrichshain',
#     'name': 'Späti',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 8833770016,
#    'lat': 52.4434355,
#    'lon': 13.3154091,
#    'tags': {'name': 'SIRIKETHA',
#     'opening_hours': 'Mo-Sa 10:00-19:00',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 8833792861,
#    'lat': 52.4441728,
#    'lon': 13.3153061,
#    'tags': {'description': 'arabische Lebensmittel, Frischfleisch',
#     'name': 'Ayoob Market',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 8839649642,
#    'lat': 52.4988108,
#    'lon': 13.2960555,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '42',
#     'addr:postcode': '10711',
#     'addr:street': 'Joachim-Friedrich-Straße',
#     'addr:suburb': 'Halensee',
#     'name': 'Kiosk & Kaffeehaus',
#     'opening_hours': 'Mo-Fr 09:00-17:00; Sa 09:00-16:00',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 8857125302,
#    'lat': 52.4824704,
#    'lon': 13.4414,
#    'tags': {'addr:housenumber': '5',
#     'addr:street': 'Wildenbruchstraße',
#     'atm': 'yes',
#     'name': 'Berlin Spätkauf',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 8890286247,
#    'lat': 52.5421037,
#    'lon': 13.39272,
#    'tags': {'name': 'Späti', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 8896048660,
#    'lat': 52.5246035,
#    'lon': 13.3396995,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '18',
#     'addr:postcode': '10555',
#     'addr:street': 'Krefelder Straße',
#     'addr:suburb': 'Moabit',
#     'level': '0',
#     'name': 'Back- und Getränkeshop Yasar',
#     'payment:cash': 'yes',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 8909368571,
#    'lat': 52.5414125,
#    'lon': 13.4129863,
#    'tags': {'name': 'Spätkauf Hutfabrik', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 8952325667,
#    'lat': 52.4606183,
#    'lon': 13.3769334,
#    'tags': {'name': 'Spätkauf',
#     'opening_hours': 'Mo-Sa 10:00-00:00',
#     'payment:maestro': 'yes',
#     'payment:mastercard': 'yes',
#     'payment:visa': 'yes',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 8989690899,
#    'lat': 52.4826253,
#    'lon': 13.381665,
#    'tags': {'addr:city': 'Berlin',
#     'addr:postcode': '12101',
#     'addr:street': 'Manfred-von-Richthofen-Straße',
#     'name': 'Ronya Minimarkt Spätkauf',
#     'opening_hours': 'Mo-Sa 12:00-22:00',
#     'opening_hours:covid19': 'same',
#     'shop': 'convenience',
#     'source': 'survey',
#     'survey:date': '2021-08-04'}},
#   {'type': 'node',
#    'id': 9050830063,
#    'lat': 52.5243949,
#    'lon': 13.3519671,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '19',
#     'addr:street': 'Alt-Moabit',
#     'delivery': 'only',
#     'description': 'Lebensmittel-Auslieferung meist per Fahrrad',
#     'name': 'Flink',
#     'shop': 'convenience',
#     'website': 'https://www.goflink.com/'}},
#   {'type': 'node',
#    'id': 9051713158,
#    'lat': 52.4722994,
#    'lon': 13.3775921,
#    'tags': {'check_date': '2021-08-31',
#     'name': 'Spätkauf & Back Shop',
#     'opening_hours': 'Mo-Fr 06:00-24:00; Sa 07:00-24:00; Su off',
#     'post_office': 'post_partner',
#     'post_office:brand': 'DHL Paketshop',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 9073418329,
#    'lat': 52.5487016,
#    'lon': 13.4499628,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9073418330,
#    'lat': 52.5499864,
#    'lon': 13.445876,
#    'tags': {'name': 'Mini Markt', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9073418332,
#    'lat': 52.5487163,
#    'lon': 13.4520471,
#    'tags': {'name': 'Späti to go',
#     'opening_hours': 'Mo-Sa 09:00-24:00,00:00-02:00; Su 13:00-20:00',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9073606224,
#    'lat': 52.5499705,
#    'lon': 13.4578066,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '95',
#     'addr:postcode': '13088',
#     'addr:street': 'Berliner Allee',
#     'name': 'Kany Getränke',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9073812247,
#    'lat': 52.5597554,
#    'lon': 13.4128012,
#    'tags': {'addr:housenumber': '49',
#     'addr:street': 'Berliner Straße',
#     'name': 'Spätkauf',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 9073823860,
#    'lat': 52.5518023,
#    'lon': 13.4662136,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '158',
#     'addr:postcode': '13088',
#     'addr:street': 'Berliner Allee',
#     'name': 'Bäckerei & Cafe - Leo',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9077238488,
#    'lat': 52.503322,
#    'lon': 13.4380163,
#    'tags': {'name': 'Baba Späti II',
#     'post_office': 'post_partner',
#     'post_office:brand': 'Hermes PaketShop',
#     'post_office:brand:wikidata': 'Q105702843',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9097623441,
#    'lat': 52.4814301,
#    'lon': 13.4311722,
#    'tags': {'description': 'Bulgarische Lebensmittel',
#     'name': 'Магазин Родина',
#     'opening_hours': 'Mo-Sa 09:00-20:00',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9114794715,
#    'lat': 52.4256948,
#    'lon': 13.4633031,
#    'tags': {'check_date': '2021-09-21', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9166121509,
#    'lat': 52.55922,
#    'lon': 13.413635,
#    'tags': {'name': 'Spätkauf', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9171564620,
#    'lat': 52.5277241,
#    'lon': 13.3357647,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '4a',
#     'addr:postcode': '10551',
#     'addr:street': 'Oldenburger Straße',
#     'name': 'Spätkauf',
#     'note': 'DHL Paketannahme',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9178061413,
#    'lat': 52.509047,
#    'lon': 13.314067,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '82',
#     'addr:postcode': '10625',
#     'addr:street': 'Leibnizstraße',
#     'name': 'Ak Spätshop',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9198286166,
#    'lat': 52.5554203,
#    'lon': 13.3749103,
#    'tags': {'name': 'Spätkauf', 'shop': 'convenience', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 9201250436,
#    'lat': 52.5715757,
#    'lon': 13.3737396,
#    'tags': {'amenity': 'cafe', 'name:signed': 'no', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9225259021,
#    'lat': 52.5584232,
#    'lon': 13.4327762,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Total',
#     'brand:wikidata': 'Q154037',
#     'brand:wikipedia': 'fr:TotalEnergies',
#     'name': 'Total',
#     'opening_hours': '24/7',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9262040839,
#    'lat': 52.5493344,
#    'lon': 13.3490006,
#    'tags': {'name': 'Spätkauf Sunside', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9264363463,
#    'lat': 52.4396254,
#    'lon': 13.3516159,
#    'tags': {'brand': 'Aral',
#     'brand:wikidata': 'Q565734',
#     'brand:wikipedia': 'en:Aral AG',
#     'name': 'Aral',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9286853352,
#    'lat': 52.4529551,
#    'lon': 13.4387484,
#    'tags': {'name': 'Britzer Spätkauf',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9298567404,
#    'lat': 52.4264522,
#    'lon': 13.3318003,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '58',
#     'addr:postcode': '12209',
#     'addr:street': 'Lorenzstraße',
#     'addr:suburb': 'Lichterfelde',
#     'name': 'Kebe',
#     'shop': 'convenience',
#     'website': 'https://www.kebe.de/'}},
#   {'type': 'node',
#    'id': 9355733804,
#    'lat': 52.5045995,
#    'lon': 13.4952382,
#    'tags': {'name': 'Alan Späti', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9408430207,
#    'lat': 52.5609764,
#    'lon': 13.3811221,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '38',
#     'addr:postcode': '13359',
#     'addr:street': 'Koloniestraße',
#     'name': 'Backshop Kiosk 38',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9410449829,
#    'lat': 52.4895086,
#    'lon': 13.4148135,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '38',
#     'addr:postcode': '10967',
#     'addr:street': 'Graefestraße',
#     'addr:suburb': 'Kreuzberg',
#     'check_date': '2022-01-11',
#     'name': 'DMX Shop',
#     'post_office': 'post_partner',
#     'post_office:brand': 'Hermes',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9420708664,
#    'lat': 52.5494884,
#    'lon': 13.4584462,
#    'tags': {'name:signed': 'no',
#     'opening_hours:signed': 'no',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9421237667,
#    'lat': 52.4895548,
#    'lon': 13.3487739,
#    'tags': {'name': 'Spätkauf', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9421237669,
#    'lat': 52.4890896,
#    'lon': 13.3488826,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '42',
#     'addr:postcode': '10823',
#     'addr:street': 'Eisenacher Straße',
#     'addr:suburb': 'Schöneberg',
#     'name': 'Späti Wunderlampe',
#     'opening_hours': 'Mo-Th 08:00-01:00, Fr,Sa 08:00-02:00',
#     'shop': 'convenience',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 9423507588,
#    'lat': 52.5490036,
#    'lon': 13.454938,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '70',
#     'addr:postcode': '13088',
#     'addr:street': 'Berliner Allee',
#     'delivery': 'yes',
#     'description': 'Lieferdienst',
#     'name': 'Flink',
#     'shop': 'convenience',
#     'website': 'https://www.goflink.com/de-DE/'}},
#   {'type': 'node',
#    'id': 9429184186,
#    'lat': 52.4981276,
#    'lon': 13.2954425,
#    'tags': {'brand': 'getir',
#     'delivery': 'only',
#     'opening_hours': '"Nur Lieferung"',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9431768938,
#    'lat': 52.5501676,
#    'lon': 13.4600182,
#    'tags': {'name': 'Helin Spätkauf',
#     'opening_hours': 'Mo-Su 08:00-24:00,00:00-02:00',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9436615201,
#    'lat': 52.5494296,
#    'lon': 13.4146269,
#    'tags': {'level': '-2', 'name': 'DB ServiceStore', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9442262038,
#    'lat': 52.5207694,
#    'lon': 13.3335452,
#    'tags': {'brand': 'REWE To Go',
#     'brand:wikidata': 'Q85224313',
#     'brand:wikipedia': 'en:REWE',
#     'name': 'REWE To Go',
#     'opening_hours': 'PH,Mo-Su 00:00-24:00+',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 9458740130,
#    'lat': 52.4802767,
#    'lon': 13.3525697,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9461313721,
#    'lat': 52.5743856,
#    'lon': 13.3598899,
#    'tags': {'name': 'Klemke Kiosk', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9482041531,
#    'lat': 52.4772428,
#    'lon': 13.4350519,
#    'tags': {'check_date': '2022-02-05',
#     'post_office': 'post_partner',
#     'post_office:brand': 'DHL',
#     'post_office:service_provider': 'DHL',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9552476503,
#    'lat': 52.4859052,
#    'lon': 13.3202346,
#    'tags': {'delivery': 'only', 'name': 'Flink', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9584532983,
#    'lat': 52.5554874,
#    'lon': 13.2255742,
#    'tags': {'name': 'Spätkauf', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9600044964,
#    'lat': 52.5492293,
#    'lon': 13.4489621,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '7',
#     'addr:postcode': '13086',
#     'addr:street': 'Langhansstraße',
#     'email': 'kontakt@der-kiosk.de',
#     'name': 'Der Kiosk',
#     'opening_hours': 'Mo-Fr 07:00-18:00; Sa 10:00-17:00',
#     'operator': 'Der Kiosk 030 Gmbh',
#     'shop': 'convenience',
#     'website': 'https://der-kiosk.de/'}},
#   {'type': 'node',
#    'id': 9609536118,
#    'lat': 52.4871035,
#    'lon': 13.3233769,
#    'tags': {'name': 'Chawla Store Kiosk', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9651437284,
#    'lat': 52.5360263,
#    'lon': 13.2039572,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '63',
#     'addr:postcode': '13597',
#     'addr:street': 'Breite Straße',
#     'description:de': 'Polnische Lebensmittel',
#     'description:en': 'polish food',
#     'description:pl': 'polska żywność',
#     'email': 'info@uzosi.de',
#     'name': 'u Zosi - Filialie Nr. 2',
#     'opening_hours': 'Mo-Fr 09:00-20:00; Sa 10:00-18:00',
#     'payment:cash': 'yes',
#     'phone': '+49 30 30345367',
#     'shop': 'convenience',
#     'website': 'https://uzosi.de/'}},
#   {'type': 'node',
#    'id': 9655515803,
#    'lat': 52.4838581,
#    'lon': 13.3552811,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '55',
#     'addr:postcode': '10827',
#     'addr:street': 'Feurigstraße',
#     'addr:suburb': 'Schöneberg',
#     'name': 'Baba Späti',
#     'post_office': 'post_partner',
#     'post_office:brand': 'Hermes PaketShop',
#     'post_office:brand:wikidata': 'Q105702843',
#     'post_office:service_provider': 'Hermes Group',
#     'shop': 'convenience',
#     'tobacco': 'yes'}},
#   {'type': 'node',
#    'id': 9657884217,
#    'lat': 52.4853083,
#    'lon': 13.3629026,
#    'tags': {'addr:housenumber': '14',
#     'addr:postcode': '10829',
#     'addr:street': 'Kolonnenstraße',
#     'name': 'SpeedySpäti',
#     'opening_hours': 'Mo-Fr 09:00-23:00; Sa 10:00-23:00',
#     'phone': '+49 162 9047866',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9668647516,
#    'lat': 52.4545008,
#    'lon': 13.624856,
#    'tags': {'name': "Karl's manufakturen MARKT",
#     'opening_hours': 'Mo-Sa 10:00-18:00',
#     'operator': "Karl's Erdbeerhof",
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9675677189,
#    'lat': 52.565593,
#    'lon': 13.3734825,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '98',
#     'addr:postcode': '13409',
#     'addr:street': 'Reginhardstraße',
#     'addr:suburb': 'Reinickendorf',
#     'name': 'Unser Kaufmann',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9710866805,
#    'lat': 52.451746,
#    'lon': 13.4385183,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '121',
#     'addr:postcode': '12347',
#     'addr:street': 'Britzer Damm',
#     'name': 'Rewands Mini Market',
#     'opening_hours': 'Mo-Sa 12:00-20:00',
#     'origin': 'arab',
#     'post_office': 'yes',
#     'post_office:brand': 'DHL',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9741677658,
#    'lat': 52.5433004,
#    'lon': 13.376407,
#    'tags': {'name': 'Alfurat Supermarkt', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 9762108276,
#    'lat': 52.4752814,
#    'lon': 13.2916625,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '22A',
#     'addr:postcode': '14199',
#     'addr:street': 'Breite Straße',
#     'name': 'Night Shop',
#     'opening_hours': 'Mo-Fr 07:30-24:00',
#     'payment:cash': 'yes',
#     'shop': 'convenience'}}]}

# %% [markdown]
# ## Creating a DataFrame from the query with lat, lon and kind(convinience)

# %%
def ret_df(data):
    df_convenience = pd.DataFrame(data['elements'])[['lat', 'lon']]
    #if i want to create an other column with the two point coordinates just run the cell below
    df_convenience['coor'] = list(zip(df_convenience.lat, df_convenience.lon))
    return df_convenience

ret_df(data)
# Out:
#            lat        lon                      coor
# 0    52.499322  13.296118  (52.4993218, 13.2961178)
# 1    52.540841  13.147471  (52.5408415, 13.1474707)
# 2    52.511047  13.462698  (52.5110467, 13.4626981)
# 3    52.509209  13.587500  (52.5092086, 13.5874999)
# 4    52.414495  13.401981  (52.4144951, 13.4019812)
# ..         ...        ...                       ...
# 844  52.454501  13.624856   (52.4545008, 13.624856)
# 845  52.565593  13.373482   (52.565593, 13.3734825)
# 846  52.451746  13.438518   (52.451746, 13.4385183)
# 847  52.543300  13.376407   (52.5433004, 13.376407)
# 848  52.475281  13.291662  (52.4752814, 13.2916625)
#
# [849 rows x 3 columns]

# %% [markdown]
# ## From DataFrame to csv file

# %%
def df_to_csv(df):
        df.to_csv(f'../livablestreets/data/{df}.csv', index=False)

# %%
df_convenience.to_csv('../livablestreets/data/checking123.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_11973/844401877.py in <module>
# ----> 1 df_convenience.to_csv('../livablestreets/data/checking123.csv', index=False)
#
# NameError: name 'df_convenience' is not defined

# %% [markdown]
# ## Function that count number of features per index(grid)

# %% [markdown]
# ### From lat1, lat2, lon1 and lon2 count how many times the same feature appear in the grid

# %%
def num_feat_per_index(index, coor):
    """from the index number(the index number will have 4 coordinates) that is the index of the 
    grid the function will return how many times the same featureappear in that grid"""
    for coor in coors:
        if coor in index:

# %%
# coords = []
# for element in parks_data['elements']:
#   if element['type'] == 'node':
#     lon = element['lon']
#     lat = element['lat']
#     coords.append((lon, lat))
#   elif 'center' in element:
#     lon = element['center']['lon']
#     lat = element['center']['lat']
#     coords.append((lon, lat))# Convert coordinates into numpy array
# X = np.array(coords)

# plt.plot(X[:, 0], X[:, 1], 'o')
# plt.title('Parks in Berlin')
# plt.xlabel('Longitude')
# plt.ylabel('Latitude')
# plt.axis('equal')
# plt.show()

# %% [markdown]
# ## try manually to make a query with laias function

# %%
from livablestreets.osm_query import query_params_osm

# %%
# def param_nodes(keys):
#     '''converts the dict into a string, returns a str for quering nodes'''
#     osm_keys = ''
#     for k,val in keys.items():
#         for v in val:
#             osm_keys += f"""node['{k}'='{v}'](area.berlin);"""
#     return osm_keys

# def param_ways(keys):
#     '''converts the dict into a string, returns a str for quering ways'''
#     osm_keys = ''
#     for k,val in keys.items():
#         for v in val:
#             osm_keys += f"""way['{k}'='{v}'](area.berlin);"""
#     return osm_keys

# def param_areas(keys):
#     '''converts the dict into a string, returns a str for quering areas'''
#     osm_keys = ''
#     for k,val in keys.items():
#         for v in val:
#             osm_keys += f"""area['{k}'='{v}'](area.berlin);"""
#     return osm_keys


# def query_params_osm(keys, feat='nodes'):
#     '''Adding keys and values as a dictionary, example: keys_values_osm = {'amenity':['bbq','cafe']}
#     several values can added to a same key as a list, returns a dict
#     arg feat = nodes, ways or areas'''

#     overpass_url = "http://overpass-api.de/api/interpreter"
#     study_area = 'area["ISO3166-2"="DE-BE"]->.berlin'

#     if feat == 'ways':
#         params = param_ways(keys)
#         out_type = 'skel'
#     if feat == 'areas':
#         params = param_areas(keys)
#         out_type = 'skel'
#     else:
#         params = param_nodes(keys)
#         out_type = 'center'

#     overpass_query = f"""
#                     [out:json];
#                     {study_area};
#                     ({params}
#                     );
#                     out {out_type};
#                     """
#     response = requests.get(overpass_url,
#                             params={'data': overpass_query})
#     return response.json()

# %% [markdown]
# ### step by step what i need to make the funcion

# %%
eating = {'amenity':['cafe','restaurant', 'food_court', 'ice_cream']}
eating_query = query_params_osm(eating, 'nodes')
df_eating = pd.DataFrame(eating_query['elements'])[['lat', 'lon']]
df_eating['coor'] = list(zip(df_eating.lat, df_eating.lon))
df_eating.to_csv('../livablestreets/data/df_eating.csv', index=False)

# %%
df_eating

# %% [markdown]
# ## make a dictionary with all the queries

# %%
queries_list = [
    #queries transportation
    {'public_transport': {'amenity':['bus_station'],
                        'bus_bay':'',
                       'highway':['bus_stop','platform'],
                       'public_transport':['stop_position','platform','station','stop_area'],
                       'railway':['station','tram_stop', 'subway_entrance']}},

    {'bike_infraestructure':  {'amenity':['bicycle_parking', 'bicycle_repair_station', 'bicycle_rental']}},

    #Queries for Cyclelanes and pedestrians
    {'cycle_paths': {'bicycle':['designated'],
                  'highway':['cycleway']}},

    #Queries for social life
    {'eating': {'amenity':['cafe','restaurant', 'food_court', 'ice_cream']}},

    {'night_life': { 'amenity':['bar','pub','biergarten', 'nightclub', 'swingerclub', 'casino']}},

    {'culture': {'amenity':['social_centre','theatre','public_bookcase',
                          'fountain', 'events_venue', 'community_centre', 'cinema',
                          'arts_centre', 'conference_centre']}},

    {'community': {'office': ['association','charity', 'coworking',
                            'educational_institution', 'employment_agency', 'foundation',
                            'ngo', 'political_party', 'research']}},

    #Queries for acitvities
    {'health_care': {'amenity':['baby_hatch','clinic','dentist',
                          'doctors', 'hospital', 'nursing_home', 'pharmacy',
                          'social_facility', 'veterinary']}},

    {'public_service': {'amenity':['courthouse','fire_station','police',
                          'post_box', 'post_office', 'townhall']}},

    {'education': {'amenity':['college','kindergarten','language_school',
                          'library', 'music_school', 'school', 'university']}},

    {'economic': {'amenity':['atm', 'bank', 'bureau_de_change']}},

    #Queries for comfort
    {'comfort_spots': {'amenity':['bbq','bench','dog_toilet',
                          '	drinking_water', 'give_box', 'shelter', 'shower',
                          'toilets', 'water_point', 'watering_place']}},

    {'leisure_spots': {'leisure':['bandstand','bird_hide','dog_park',
                          'firepit', 'swimming_pool', 'stadium', 'sports_centre',
                          'pitch', 'picnic_table', 'fitness_centre'],
                     'historic':''}},

    #querie for areas
    {'leirsure_areas': {'leisure':['park','garden','swimming_area',
                          'playground', 'nature_reserve', 'marina'],
                     'landuse':['forest']}}
            ]

# %% [markdown]
# ### query - df and csv file public_transport

# %%
# public_transport = [{'amenity':['cafe','restaurant', 'food_court', 'ice_cream']},

#     { 'amenity':['bar','pub','biergarten', 'nightclub', 'swingerclub', 'casino']},

#      {'amenity':['social_centre','theatre','public_bookcase',
#                           'fountain', 'events_venue', 'community_centre', 'cinema',
#                           'arts_centre', 'conference_centre']}]
# for querie in public_transport:
#     new_querie = query_params_osm(querie, 'nodes')

# df_public_transport = pd.DataFrame(new_querie['elements'])[['lat', 'lon']]
# df_public_transport['coor'] = list(zip(df_public_transport.lat, df_public_transport.lon))
# df_public_transport.to_csv('../livablestreets/data/df_public_transport.csv', index=False)
# df_public_transport

# %% [markdown]
# ###  query - df and csv file bike_infraestructure

# %%
bike_infraestructure =  {'amenity':['bicycle_parking', 'bicycle_repair_station', 'bicycle_rental']}
#for querie in bike_infraestructure:
new_querie = query_params_osm(bike_infraestructure, 'nodes')

df_bike_infraestructure = pd.DataFrame(new_querie['elements'])[['lat', 'lon']]
df_bike_infraestructure['coor'] = list(zip(df_bike_infraestructure.lat, df_bike_infraestructure.lon))
df_bike_infraestructure.to_csv('../livablestreets/data/df_public_transport.csv', index=False)
df_bike_infraestructure
# Out:
#              lat        lon                      coor
# 0      52.458468  13.576228  (52.4584678, 13.5762278)
# 1      52.542327  13.365857  (52.5423271, 13.3658567)
# 2      52.545369  13.457723  (52.5453694, 13.4577226)
# 3      52.448084  13.444090  (52.4480841, 13.4440895)
# 4      52.452565  13.449582  (52.4525653, 13.4495822)
# ...          ...        ...                       ...
# 10211  52.511034  13.322931  (52.5110344, 13.3229313)
# 10212  52.510979  13.323013  (52.5109792, 13.3230128)
# 10213  52.434013  13.583049  (52.4340131, 13.5830493)
# 10214  52.434655  13.582704  (52.4346552, 13.5827044)
# 10215  52.455237  13.250278  (52.4552368, 13.2502781)
#
# [10216 rows x 3 columns]

# %% [markdown]
# ### eating

# %%
eating = {'amenity':['cafe','restaurant', 'food_court', 'ice_cream']}
new_querie = query_params_osm(eating, 'nodes')
df_eating = pd.DataFrame(new_querie['elements'])[['lat', 'lon']]
df_eating['coor'] = list(zip(df_eating.lat, df_eating.lon))
df_eating.to_csv('../livablestreets/data/df_eating.csv', index=False)
df_eating
# Out:
#             lat        lon                      coor
# 0     52.506911  13.322821   (52.506911, 13.3228214)
# 1     52.506212  13.318081  (52.5062119, 13.3180811)
# 2     52.507320  13.320780  (52.5073199, 13.3207804)
# 3     52.506318  13.284626  (52.5063184, 13.2846256)
# 4     52.538855  13.396097  (52.5388551, 13.3960965)
# ...         ...        ...                       ...
# 6685  52.522585  13.367956  (52.5225849, 13.3679556)
# 6686  52.539688  13.413942  (52.5396884, 13.4139424)
# 6687  52.402463  13.525812  (52.4024631, 13.5258121)
# 6688  52.546867  13.202493  (52.5468666, 13.2024933)
# 6689  52.592225  13.349345  (52.5922254, 13.3493445)
#
# [6690 rows x 3 columns]

# %% [markdown]
# ### nighlife

# %%
night_life = { 'amenity':['bar','pub','biergarten', 'nightclub', 'swingerclub', 'casino']}
new_querie = query_params_osm(night_life, 'nodes')
df_night_life = pd.DataFrame(new_querie['elements'])[['lat', 'lon']]
df_night_life['coor'] = list(zip(df_night_life.lat, df_night_life.lon))
df_night_life.to_csv('../livablestreets/data/df_night_life.csv', index=False)
df_night_life
# Out:
#             lat        lon                      coor
# 0     52.433364  13.190734   (52.4333644, 13.190734)
# 1     52.420088  13.176346  (52.4200885, 13.1763456)
# 2     52.539846  13.352146  (52.5398463, 13.3521465)
# 3     52.569808  13.310130  (52.5698075, 13.3101301)
# 4     52.563820  13.328849     (52.56382, 13.328849)
# ...         ...        ...                       ...
# 2057  52.607145  13.319713  (52.6071447, 13.3197133)
# 2058  52.446545  13.574963  (52.4465449, 13.5749629)
# 2059  52.546160  13.348202  (52.5461605, 13.3482024)
# 2060  52.403460  13.525824  (52.4034603, 13.5258243)
# 2061  52.559893  13.381292  (52.5598931, 13.3812922)
#
# [2062 rows x 3 columns]

# %% [markdown]
# ### culture

# %%
culture = {'amenity':['social_centre','theatre','public_bookcase',
                          'fountain', 'events_venue', 'community_centre', 'cinema',
                          'arts_centre', 'conference_centre']}
new_querie = query_params_osm(culture, 'nodes')
df_culture = pd.DataFrame(new_querie['elements'])[['lat', 'lon']]
df_culture['coor'] = list(zip(df_culture.lat, df_culture.lon))
df_culture.to_csv('../livablestreets/data/df_culture.csv', index=False)
df_culture
# Out:
#             lat        lon                      coor
# 0     52.534378  13.359623  (52.5343784, 13.3596231)
# 1     52.494042  13.429187  (52.4940425, 13.4291868)
# 2     52.523922  13.388879  (52.5239216, 13.3888786)
# 3     52.523624  13.388621  (52.5236239, 13.3886211)
# 4     52.520667  13.388505  (52.5206669, 13.3885051)
# ...         ...        ...                       ...
# 1033  52.515916  13.391388   (52.5159163, 13.391388)
# 1034  52.567656  13.379357  (52.5676563, 13.3793571)
# 1035  52.402864  13.524733  (52.4028637, 13.5247327)
# 1036  52.550510  13.442311  (52.5505098, 13.4423114)
# 1037  52.560698  13.380293  (52.5606977, 13.3802929)
#
# [1038 rows x 3 columns]

# %% [markdown]
# ### comunity

# %%
community = {'office': ['association','charity', 'coworking',
                            'educational_institution', 'employment_agency', 'foundation',
                            'ngo', 'political_party', 'research']}
new_querie = query_params_osm(community, 'nodes')
df_community = pd.DataFrame(new_querie['elements'])[['lat', 'lon']]
df_community['coor'] = list(zip(df_community.lat, df_community.lon))
df_community.to_csv('../livablestreets/data/df_community.csv', index=False)
df_community
# Out:
#            lat        lon                      coor
# 0    52.513551  13.302865  (52.5135508, 13.3028655)
# 1    52.546772  13.356516  (52.5467722, 13.3565162)
# 2    52.529530  13.401782  (52.5295304, 13.4017825)
# 3    52.526073  13.314284  (52.5260727, 13.3142839)
# 4    52.541684  13.385855  (52.5416843, 13.3858547)
# ..         ...        ...                       ...
# 666  52.570563  13.361659  (52.5705632, 13.3616594)
# 667  52.539439  13.383822  (52.5394385, 13.3838217)
# 668  52.465889  13.435643  (52.4658891, 13.4356434)
# 669  52.408996  13.603854  (52.4089961, 13.6038543)
# 670  52.535492  13.356177  (52.5354917, 13.3561773)
#
# [671 rows x 3 columns]

# %% [markdown]
# ### health care

# %%
health_care = {'amenity':['baby_hatch','clinic','dentist',
                          'doctors', 'hospital', 'nursing_home', 'pharmacy',
                          'social_facility', 'veterinary']}
new_querie = query_params_osm(health_care, 'nodes')
df_health_care = pd.DataFrame(new_querie['elements'])[['lat', 'lon']]
df_health_care['coor'] = list(zip(df_health_care.lat, df_health_care.lon))
df_health_care.to_csv('../livablestreets/data/df_health_care.csv', index=False)
df_health_care
# Out:
#             lat        lon                      coor
# 0     52.540741  13.486602  (52.5407412, 13.4866016)
# 1     52.531835  13.469654  (52.5318353, 13.4696536)
# 2     52.527555  13.468513  (52.5275552, 13.4685134)
# 3     52.489390  13.450570  (52.4893898, 13.4505704)
# 4     52.510509  13.395946  (52.5105088, 13.3959459)
# ...         ...        ...                       ...
# 3141  52.408948  13.404777  (52.4089479, 13.4047771)
# 3142  52.504650  13.342222  (52.5046496, 13.3422222)
# 3143  52.636514  13.493378  (52.6365143, 13.4933777)
# 3144  52.487032  13.436802  (52.4870325, 13.4368022)
# 3145  52.483908  13.443282  (52.4839078, 13.4432818)
#
# [3146 rows x 3 columns]

# %% [markdown]
# ### public service

# %%
public_service = {'amenity':['courthouse','fire_station','police',
                          'post_box', 'post_office', 'townhall']}
new_querie = query_params_osm(public_service, 'nodes')
df_public_service = pd.DataFrame(new_querie['elements'])[['lat', 'lon']]
df_public_service['coor'] = list(zip(df_public_service.lat, df_public_service.lon))
df_public_service.to_csv('../livablestreets/data/df_public_service.csv', index=False)
df_public_service
# Out:
#             lat        lon                      coor
# 0     52.401683  13.574304   (52.401683, 13.5743044)
# 1     52.489074  13.322506    (52.489074, 13.322506)
# 2     52.524506  13.346521  (52.5245064, 13.3465209)
# 3     52.533663  13.353639  (52.5336632, 13.3536389)
# 4     52.524022  13.352566   (52.524022, 13.3525663)
# ...         ...        ...                       ...
# 2642  52.544889  13.367169  (52.5448891, 13.3671687)
# 2643  52.577459  13.357799  (52.5774589, 13.3577993)
# 2644  52.537720  13.385562  (52.5377196, 13.3855617)
# 2645  52.431473  13.714988  (52.4314732, 13.7149883)
# 2646  52.592534  13.358247  (52.5925342, 13.3582473)
#
# [2647 rows x 3 columns]

# %% [markdown]
# ### education

# %%
education = {'amenity':['college','kindergarten','language_school',
                          'library', 'music_school', 'school', 'university']}
new_querie = query_params_osm(education, 'nodes')
df_education = pd.DataFrame(new_querie['elements'])[['lat', 'lon']]
df_education['coor'] = list(zip(df_education.lat, df_education.lon))
df_education.to_csv('../livablestreets/data/df_education.csv', index=False)
df_education
# Out:
#             lat        lon                      coor
# 0     52.531245  13.347514  (52.5312448, 13.3475136)
# 1     52.530777  13.470838  (52.5307772, 13.4708382)
# 2     52.515564  13.404136  (52.5155636, 13.4041356)
# 3     52.501536  13.433399  (52.5015358, 13.4333992)
# 4     52.528158  13.538715   (52.5281578, 13.538715)
# ...         ...        ...                       ...
# 1651  52.417774  13.366480  (52.4177738, 13.3664801)
# 1652  52.465576  13.388545  (52.4655764, 13.3885447)
# 1653  52.565911  13.359942  (52.5659109, 13.3599422)
# 1654  52.538581  13.413392  (52.5385815, 13.4133919)
# 1655  52.503716  13.423080  (52.5037159, 13.4230798)
#
# [1656 rows x 3 columns]

# %% [markdown]
# ### economics

# %%
economic = {'amenity':['atm', 'bank', 'bureau_de_change']}
new_querie = query_params_osm(economic, 'nodes')
df_economic = pd.DataFrame(new_querie['elements'])[['lat', 'lon']]
df_economic['coor'] = list(zip(df_economic.lat, df_economic.lon))
df_economic.to_csv('../livablestreets/data/df_economic.csv', index=False)
df_economic
# Out:
#             lat        lon                      coor
# 0     52.486668  13.319723   (52.4866675, 13.319723)
# 1     52.489024  13.322494  (52.4890244, 13.3224941)
# 2     52.530339  13.471082  (52.5303395, 13.4710823)
# 3     52.524670  13.465618  (52.5246695, 13.4656184)
# 4     52.523744  13.398627  (52.5237445, 13.3986266)
# ...         ...        ...                       ...
# 1286  52.509889  13.462890  (52.5098888, 13.4628902)
# 1287  52.531944  13.349778  (52.5319436, 13.3497784)
# 1288  52.526389  13.536751  (52.5263885, 13.5367511)
# 1289  52.499601  13.416856  (52.4996006, 13.4168564)
# 1290  52.565093  13.364001  (52.5650926, 13.3640012)
#
# [1291 rows x 3 columns]

# %% [markdown]
# ### comfort sports

# %%
comfort_spots = {'amenity':['bbq','bench','dog_toilet',
                          '	drinking_water', 'give_box', 'shelter', 'shower',
                          'toilets', 'water_point', 'watering_place']}
new_querie = query_params_osm(comfort_spots, 'nodes')
df_comfort_spots = pd.DataFrame(new_querie['elements'])[['lat', 'lon']]
df_comfort_spots['coor'] = list(zip(df_comfort_spots.lat, df_comfort_spots.lon))
df_comfort_spots.to_csv('../livablestreets/data/df_comfort_spots.csv', index=False)
df_comfort_spots
# Out:
#            lat        lon                      coor
# 0    52.525003  13.335498  (52.5250027, 13.3354981)
# 1    52.550683  13.334696    (52.550683, 13.334696)
# 2    52.518503  13.406268  (52.5185032, 13.4062678)
# 3    52.517545  13.373869  (52.5175448, 13.3738695)
# 4    52.563938  13.326712  (52.5639385, 13.3267121)
# ..         ...        ...                       ...
# 835  52.497616  13.403725  (52.4976155, 13.4037248)
# 836  52.497618  13.403774  (52.4976176, 13.4037738)
# 837  52.497411  13.403136  (52.4974107, 13.4031361)
# 838  52.497382  13.403128  (52.4973823, 13.4031284)
# 839  52.556408  13.393655  (52.5564081, 13.3936554)
#
# [840 rows x 3 columns]

# %% [markdown]
# ### leisure sports

# %%
leisure_spots = {'leisure':['bandstand','bird_hide','dog_park',
                          'firepit', 'swimming_pool', 'stadium', 'sports_centre',
                          'pitch', 'picnic_table', 'fitness_centre'],
                     'historic':''}
new_querie = query_params_osm(leisure_spots, 'nodes')
df_leisure_spots = pd.DataFrame(new_querie['elements'])[['lat', 'lon']]
df_leisure_spots['coor'] = list(zip(df_leisure_spots.lat, df_leisure_spots.lon))
df_leisure_spots.to_csv('../livablestreets/data/df_leisure_spots.csv', index=False)
df_leisure_spots
# Out:
#             lat        lon                      coor
# 0     52.490552  13.319267   (52.490552, 13.3192668)
# 1     52.549548  13.571724   (52.5495479, 13.571724)
# 2     52.488613  13.319393  (52.4886132, 13.3193928)
# 3     52.429666  13.216574  (52.4296658, 13.2165739)
# 4     52.428840  13.216957  (52.4288397, 13.2169575)
# ...         ...        ...                       ...
# 1815  52.566072  13.358231  (52.5660722, 13.3582312)
# 1816  52.576728  13.348270  (52.5767284, 13.3482695)
# 1817  52.506138  13.403830  (52.5061382, 13.4038295)
# 1818  52.592783  13.360090  (52.5927826, 13.3600901)
# 1819  52.566199  13.386870  (52.5661993, 13.3868697)
#
# [1820 rows x 3 columns]

# %%
###leisure areas

# %%
# {'leirsure_areas': {'leisure':['park','garden','swimming_area',
#                           'playground', 'nature_reserve', 'marina'],
#                      'landuse':['forest']}}

# %%
small_queries = pd.DataFrame(new_querie['elements'])[['lat', 'lon']]
small_queries['coor'] = list(zip(small_queries.lat, small_queries.lon))
small_queries.to_csv('../livablestreets/data/small_queries.csv', index=False)
small_queries

# %%
amenity = {'amenity':['bar','pub','biergarten', 'nightclub', 'swingerclub', 'casino']}
amenity  = query_params_osm(amenity, 'nodes')

# %%
amenity
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.58.1 bb9ccb2d',
#  'osm3s': {'timestamp_osm_base': '2022-06-01T10:42:28Z',
#   'timestamp_areas_base': '2022-06-01T10:16:09Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 26865440,
#    'lat': 52.4333644,
#    'lon': 13.190734,
#    'tags': {'amenity': 'biergarten',
#     'name': 'Spinnerbrücke',
#     'note': 'Motorradtreff',
#     'toilets:wheelchair': 'no',
#     'website': 'http://www.spinner-bruecke.de/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 27318009,
#    'lat': 52.4200885,
#    'lon': 13.1763456,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '260',
#     'addr:postcode': '14109',
#     'addr:street': 'Kronprinzessinnenweg',
#     'amenity': 'biergarten',
#     'contact:email': 'info@loretta-berlin.de',
#     'contact:fax': '+49 30 80105334',
#     'contact:phone': '+49 30 80105333',
#     'contact:website': 'https://www.loretta-wannsee.de/biergarten/',
#     'name': 'Loretta',
#     'opening_hours': '12:00+',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 35300986,
#    'lat': 52.5398463,
#    'lon': 13.3521465,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '10',
#     'addr:postcode': '13353',
#     'addr:street': 'Nordufer',
#     'addr:suburb': 'Wedding',
#     'amenity': 'pub',
#     'name': 'Deichgraf',
#     'toilets:wheelchair': 'yes',
#     'website': 'http://www.gaststaette-deichgraf.de/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 78447148,
#    'lat': 52.5698075,
#    'lon': 13.3101301,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '10',
#     'addr:postcode': '13403',
#     'addr:street': 'Klixstraße',
#     'addr:suburb': 'Reinickendorf',
#     'amenity': 'pub',
#     'name': 'ZobelKlix',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 79675952,
#    'lat': 52.56382,
#    'lon': 13.328849,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '16',
#     'addr:postcode': '13405',
#     'addr:street': 'Scharnweberstraße',
#     'amenity': 'bar',
#     'brewery': 'various',
#     'name': "Albert's",
#     'phone': '+49 30 36726707',
#     'smoking': 'outside',
#     'toilets:wheelchair': 'no',
#     'website': 'https://www.alberts-restaurants.de/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 84904956,
#    'lat': 52.5712131,
#    'lon': 13.3134197,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:suburb': 'Reinickendorf',
#     'amenity': 'pub',
#     'name': 'Eichborneck',
#     'phone': '+49-30',
#     'smoking': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 86001835,
#    'lat': 52.512033,
#    'lon': 13.3919416,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '30',
#     'addr:postcode': '10117',
#     'addr:street': 'Mohrenstraße',
#     'amenity': 'bar',
#     'email': 'info@bellboyberlin.com',
#     'min_age': '25',
#     'name': 'Bellboy Berlin',
#     'opening_hours': 'Tu-Su 18:00-late',
#     'phone': '+49 30 20077070',
#     'toilets:wheelchair': 'yes',
#     'website': 'https://bellboybar.com/home/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 86005430,
#    'lat': 52.5129305,
#    'lon': 13.3912298,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '57',
#     'addr:postcode': '10117',
#     'addr:street': 'Charlottenstraße',
#     'amenity': 'bar',
#     'name': 'Newton Bar',
#     'operator': 'LaggnerGruppe',
#     'website': 'http://www.newton-bar.de',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 89274696,
#    'lat': 52.5235991,
#    'lon': 13.4109696,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '1-3',
#     'addr:postcode': '10178',
#     'addr:street': 'Memhardstraße',
#     'addr:suburb': 'Mitte',
#     'amenity': 'pub',
#     'brewery': 'yes',
#     'contact:website': 'http://berlin.braufactum.de/',
#     'cuisine': 'barbecue;burger',
#     'name': 'Braufactum',
#     'opening_hours': '11:00+',
#     'outdoor_seating': 'yes',
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 89957618,
#    'lat': 52.5840688,
#    'lon': 13.302578,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '68',
#     'addr:postcode': '13509',
#     'addr:street': 'Ernststraße',
#     'addr:suburb': 'Borsigwalde',
#     'amenity': 'pub',
#     'name': 'Sportler-Eck',
#     'phone': '+49 30 4327668',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 111644760,
#    'lat': 52.5655612,
#    'lon': 13.3209279,
#    'tags': {'amenity': 'bar',
#     'name': 'No Limit Shishabar',
#     'phone': '+4915788084160'}},
#   {'type': 'node',
#    'id': 137549003,
#    'lat': 52.5699596,
#    'lon': 13.3138632,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '23',
#     'addr:postcode': '13403',
#     'addr:street': 'Graf-Haeseler-Straße',
#     'addr:suburb': 'Reinickendorf',
#     'amenity': 'pub',
#     'name': 'Zum feuchten Grafen',
#     'phone': '+49-30-4127765'}},
#   {'type': 'node',
#    'id': 137549008,
#    'lat': 52.5708788,
#    'lon': 13.3158208,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '67a',
#     'addr:postcode': '13403',
#     'addr:street': 'Auguste-Viktoria-Allee',
#     'addr:suburb': 'Reinickendorf',
#     'amenity': 'pub',
#     'name': 'Old Sloth',
#     'phone': '+49 30 81868255'}},
#   {'type': 'node',
#    'id': 137549010,
#    'lat': 52.5688285,
#    'lon': 13.3170085,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '25',
#     'addr:postcode': '13403',
#     'addr:street': 'General-Barby-Straße',
#     'addr:suburb': 'Reinickendorf',
#     'amenity': 'pub',
#     'contact:facebook': 'https://www.facebook.com/chilloutbar',
#     'contact:phone': '+49-30-46994340',
#     'contact:website': 'http://www.chillout-berlin.de/',
#     'name': 'ChillOut Bar',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 137549024,
#    'lat': 52.5700374,
#    'lon': 13.3221149,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '84',
#     'addr:postcode': '13403',
#     'addr:street': 'Auguste-Viktoria-Allee',
#     'addr:suburb': 'Reinickendorf',
#     'amenity': 'pub',
#     'name': 'Bären-Eck',
#     'opening_hours': 'Mo-Su 10:00-22:00',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 139671037,
#    'lat': 52.5342924,
#    'lon': 13.1421398,
#    'tags': {'amenity': 'pub', 'name': 'Grenzeck', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 140274896,
#    'lat': 52.5682701,
#    'lon': 13.367889,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '18',
#     'addr:postcode': '13409',
#     'addr:street': 'Amendestraße',
#     'addr:suburb': 'Reinickendorf',
#     'amenity': 'pub',
#     'facebook': 'https://www.facebook.com/pages/category/Speakeasy/Haus-Bierwerk-103429807717152/',
#     'name': 'Haus Bierwerk',
#     'opening_hours': 'Mo-Th 12:00-21:00; Fr,Sa 21:00+; Su off',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 140274903,
#    'lat': 52.5754322,
#    'lon': 13.3303066,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '103',
#     'addr:postcode': '13403',
#     'addr:street': 'Waldstraße',
#     'addr:suburb': 'Reinickendorf',
#     'amenity': 'pub',
#     'name': "Potter's Inn",
#     'opening_hours': 'Su-Th 16:00-22:00, Fr,Sa 17:00-18:00+',
#     'operator': 'John Herr',
#     'phone': '+49-30-41708341',
#     'wheelchair': 'no',
#     'wheelchair:description': 'Stufen am Eingang'}},
#   {'type': 'node',
#    'id': 149607257,
#    'lat': 52.5442039,
#    'lon': 13.4129805,
#    'tags': {'amenity': 'bar', 'name': 'en passant', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 150667269,
#    'lat': 52.5431648,
#    'lon': 13.3566864,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '58',
#     'addr:postcode': '13353',
#     'addr:street': 'Triftstraße',
#     'addr:suburb': 'Wedding',
#     'amenity': 'pub',
#     'contact:email': 'mail@irish-pub.berlin',
#     'contact:phone': '+49 30 49080806',
#     'contact:website': 'http://tipperary.berlin',
#     'cuisine': 'irish',
#     'indoor_seating': 'yes',
#     'name': 'The Tipperary',
#     'opening_hours': 'Mo-Fr 15:00+; Sa,Su 14:00-18:00+',
#     'operator': 'Christian Schirren',
#     'outdoor_seating': 'yes',
#     'smoking': 'outside',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Hat nur eine kleine Stufe und man kann über die Terrasse rein. Das WC ist sehr eng. Hat eine Rampe.'}},
#   {'type': 'node',
#    'id': 150989193,
#    'lat': 52.5642761,
#    'lon': 13.3265108,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '137',
#     'addr:postcode': '13405',
#     'addr:street': 'Scharnweberstraße',
#     'addr:suburb': 'Reinickendorf',
#     'amenity': 'pub',
#     'check_date:opening_hours': '2021-09-30',
#     'name': 'ROJ Musik Bar',
#     'opening_hours': 'Mo-Su 12:00-04:00',
#     'phone': '+49 30 41703586',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 150990860,
#    'lat': 52.5235968,
#    'lon': 13.3007288,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '46',
#     'addr:postcode': '10589',
#     'addr:street': 'Tauroggener Straße',
#     'addr:suburb': 'Charlottenburg',
#     'amenity': 'pub',
#     'name': 'Café Egal und Radlstation',
#     'note': 'Café, Bar, Fahrradwerkstatt',
#     'opening_hours': 'Mo-Su 10:00-24:00',
#     'phone': '+49 30 34509919',
#     'website': 'http://radlstation-berlin.de/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 167013475,
#    'lat': 52.4916944,
#    'lon': 13.4389954,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '14c',
#     'addr:postcode': '10999',
#     'addr:street': 'Ratiborstraße',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'biergarten',
#     'brewery': 'yes',
#     'internet_access': 'wlan',
#     'name': 'Jockel',
#     'opening_hours': 'Mo-Su 10:00-22:00',
#     'outdoor_seating': 'yes',
#     'phone': '+49 30 69598060',
#     'smoking': 'outside',
#     'website': 'https://www.biergartenjockel.de/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 175685782,
#    'lat': 52.5965582,
#    'lon': 13.3330486,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '91',
#     'addr:postcode': '13437',
#     'addr:street': 'Oranienburger Straße',
#     'addr:suburb': 'Wittenau',
#     'amenity': 'pub',
#     'contact:phone': '+49 30 41190562',
#     'name': 'Märkische Bierstuben',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 186054004,
#    'lat': 52.5726395,
#    'lon': 13.3048085,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '40',
#     'addr:postcode': '13403',
#     'addr:street': 'Otisstraße',
#     'amenity': 'pub',
#     'contact:phone': '+49 30 41508648',
#     'contact:website': 'https://carolas-dorfkrug.beepworld.de',
#     'name': 'Dorfkrug',
#     'opening_hours': 'Mo-Sa 12:00-22:00; Su 12:00-18:00',
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 208510718,
#    'lat': 52.5640793,
#    'lon': 13.3644914,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '109',
#     'addr:postcode': '13409',
#     'addr:street': 'Residenzstraße',
#     'addr:suburb': 'Reinickendorf',
#     'amenity': 'pub',
#     'indoor_seating': 'yes',
#     'name': 'Kastanienwäldchen',
#     'opening_hours': 'Mo-Fr 11:00-24:00; Sa 11:00-23:00',
#     'outdoor_seating': 'yes',
#     'url': 'http://www.kastanienwaeldchen.de',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 248651127,
#    'lat': 52.5295259,
#    'lon': 13.3956385,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '2',
#     'addr:postcode': '10115',
#     'addr:street': 'Bergstraße',
#     'addr:suburb': 'Mitte',
#     'amenity': 'bar',
#     'contact:phone': '+49 30 28389121',
#     'description': 'Bar mit Kulturprogramm im kleinen Kinosaal (Zinema)',
#     'name': 'Z-Bar',
#     'opening_hours': '19:00+',
#     'opening_hours:covid19': 'same',
#     'operator': 'Kulturverein Wechsel e.V.',
#     'outdoor_seating': 'yes',
#     'phone': '+493028389121',
#     'smoking': 'outside',
#     'start_date': '1994',
#     'website': 'http://www.z-bar.de/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 250588095,
#    'lat': 52.5355911,
#    'lon': 13.4200871,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '8',
#     'addr:postcode': '10405',
#     'addr:street': 'Rykestraße',
#     'addr:suburb': 'Prenzlauer Berg',
#     'amenity': 'pub',
#     'contact:email': 'info01@yard-musikkneipe.de',
#     'contact:fax': '+49-30-4446413',
#     'contact:phone': '+49-30-4424211',
#     'contact:website': 'http://www.yard-musikkneipe.de/',
#     'name': 'Yard',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 255049657,
#    'lat': 52.4337259,
#    'lon': 13.1642419,
#    'tags': {'amenity': 'biergarten',
#     'name': 'Haus Sanssouci',
#     'opening_hours': 'We,Th,Su 12:00-20:30; Fr,Sa 12:00-21:00',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 257708389,
#    'lat': 52.5406075,
#    'lon': 13.2066054,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '1',
#     'addr:postcode': '13585',
#     'addr:street': 'Neuendorfer Straße',
#     'addr:suburb': 'Spandau',
#     'amenity': 'biergarten',
#     'brewery': 'yes',
#     'capacity': '400',
#     'name': 'Brauhaus Spandau',
#     'opening_hours': 'PH,Mo-Su 11:00-23:00',
#     'outdoor_seating': 'yes',
#     'smoking': 'outside',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 259845846,
#    'lat': 52.4913696,
#    'lon': 13.3931533,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '18',
#     'addr:postcode': '10961',
#     'addr:street': 'Gneisenaustraße',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'nightclub',
#     'name': 'Junction-Bar',
#     'phone': '+49306946602',
#     'website': 'http://www.junction-bar.de/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 260050809,
#    'lat': 52.5129735,
#    'lon': 13.4201313,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housename': 'c-base',
#     'addr:housenumber': '20',
#     'addr:postcode': '10179',
#     'addr:street': 'Rungestraße',
#     'addr:suburb': 'Mitte',
#     'alt_name': 'cbase',
#     'amenity': 'pub',
#     'contact:mastodon': 'cbase@mastodon.social',
#     'contact:phone': '+49 30 28599300',
#     'contact:twitter': '@cbase',
#     'contact:website': 'https://www.c-base.org/',
#     'drink:club-mate': 'served',
#     'internet_access': 'wlan',
#     'leisure': 'hackerspace',
#     'name': 'c-base',
#     'opening_hours': '"Only for events open for public. Else it\'s members only"',
#     'opening_hours:url': 'https://c-base.org/calendar',
#     'operator:type': 'community',
#     'smoking': 'yes',
#     'toilets': 'yes',
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'no',
#     'wheelchair:description': 'public areas are accessible, member areas in the basement are not.',
#     'wikidata': 'Q265688',
#     'wikipedia': 'de:C-base'}},
#   {'type': 'node',
#    'id': 262194409,
#    'lat': 52.5334428,
#    'lon': 13.4162759,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '27',
#     'addr:postcode': '10405',
#     'addr:street': 'Belforter Straße',
#     'addr:suburb': 'Prenzlauer Berg',
#     'amenity': 'pub',
#     'contact:email': 'enddorn@online.de',
#     'contact:phone': '+49-30-4408380',
#     'name': 'Enddorn',
#     'url': 'http://www.enddorn-berlin.de/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 262818281,
#    'lat': 52.5232268,
#    'lon': 13.4164254,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '7',
#     'addr:postcode': '10178',
#     'addr:street': 'Alexanderstraße',
#     'amenity': 'nightclub',
#     'name': 'ASeven Club',
#     'opening_hours': 'Fr,Sa 22:00-06:00, Su 16:00-24:00',
#     'website': 'https://www.aseven.de',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 267780050,
#    'lat': 52.5363657,
#    'lon': 13.425073,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '6',
#     'addr:postcode': '10405',
#     'addr:street': 'Christburger Straße',
#     'addr:suburb': 'Prenzlauer Berg',
#     'amenity': 'bar',
#     'check_date:opening_hours': '2021-12-14',
#     'contact:website': 'http://www.bar-immertreu.de/',
#     'name': 'Immertreu',
#     'opening_hours': '20:00+',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 268002620,
#    'lat': 52.5231963,
#    'lon': 13.4769761,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '225',
#     'addr:postcode': '10367',
#     'addr:street': 'Storkower Straße',
#     'addr:suburb': 'Fennpfuhl',
#     'amenity': 'pub',
#     'contact:email': 'club.schlauch@googlemail.com',
#     'name': 'Studentenclub Schlauch',
#     'opening_hours': 'Th, Sa 18:00-22:00',
#     'opening_hours:signed': 'Th,Sa- 18:00-22:00',
#     'url': 'http://www.schlauchberlin.de/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 269414693,
#    'lat': 52.5414032,
#    'lon': 13.3684921,
#    'tags': {'amenity': 'bar',
#     'indoor_seating': 'yes',
#     'name': 'Tiger Karaoke',
#     'opening_hours:signed': 'no',
#     'outdoor_seating': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 270814670,
#    'lat': 52.4286425,
#    'lon': 13.2155914,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '75',
#     'addr:postcode': '14129',
#     'addr:street': 'Wasgenstraße',
#     'addr:suburb': 'Schlachtensee',
#     'amenity': 'pub',
#     'contact:phone': '+49 30 80496499',
#     'contact:website': 'https://haus14.com/',
#     'level': '1',
#     'name': 'KlubHaus14',
#     'old_name': 'Club A18',
#     'opening_hours': 'We-Sa 18:00-23:00',
#     'opening_hours:covid19': 'closed',
#     'operator': 'Haus14 eG iG'}},
#   {'type': 'node',
#    'id': 270961500,
#    'lat': 52.5550162,
#    'lon': 13.3616898,
#    'tags': {'amenity': 'pub',
#     'name': 'Seequell',
#     'opening_hours': 'PH,Mo-Su 12:00-18:00+',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 272607235,
#    'lat': 52.4594244,
#    'lon': 13.5779548,
#    'tags': {'amenity': 'pub',
#     'name': 'Union Tanke',
#     'opening_hours': '"Bei Heimspiel 1. FC Union Berlin"',
#     'toilets:wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 273756679,
#    'lat': 52.4614742,
#    'lon': 13.339716,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '67',
#     'addr:postcode': '12157',
#     'addr:street': 'Bismarckstraße',
#     'addr:suburb': 'Steglitz',
#     'amenity': 'pub',
#     'name': "Sportsbar Heinrich's",
#     'opening_hours': 'Mo-Fr 12:00-23:00; Sa,Su 10:00-23:00',
#     'url': 'http://www.sportsbar-heinrichs.de/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 275375441,
#    'lat': 52.4882652,
#    'lon': 13.361927,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '22',
#     'addr:postcode': '10827',
#     'addr:street': 'Crellestraße',
#     'addr:suburb': 'Schöneberg',
#     'amenity': 'bar',
#     'brewery': 'Pilsator',
#     'contact:website': 'http://cafenostalgie-berlin.de/',
#     'internet_access': 'no',
#     'name': 'Café Nostalgie',
#     'smoking': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 276134997,
#    'lat': 52.429983,
#    'lon': 13.3540107,
#    'tags': {'amenity': 'biergarten',
#     'name': "Balke's Park-Treff",
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 276762554,
#    'lat': 52.4689788,
#    'lon': 13.4354663,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '122',
#     'addr:postcode': '12051',
#     'addr:street': 'Emser Straße',
#     'addr:suburb': 'Neukölln',
#     'amenity': 'bar',
#     'name': 'Schloss Neuschweinsteiger',
#     'opening_hours': '19:00-03:00',
#     'website': 'http://www.schloss-neuschweinsteiger.de',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 278266065,
#    'lat': 52.5058484,
#    'lon': 13.4663943,
#    'tags': {'amenity': 'pub',
#     'name': 'Geronimo',
#     'smoking': 'yes',
#     'sport': 'table_soccer',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 278876760,
#    'lat': 52.512183,
#    'lon': 13.4617297,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '15',
#     'addr:postcode': '10247',
#     'addr:street': 'Mainzer Straße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'pub',
#     'contact:website': 'http://www.halford-berlin.de',
#     'indoor_seating': 'yes',
#     'name': 'Rockcafé Halford',
#     'outdoor_seating': 'yes',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 278876847,
#    'lat': 52.5120463,
#    'lon': 13.4613169,
#    'tags': {'amenity': 'bar',
#     'entrance': 'yes',
#     'indoor_seating': 'yes',
#     'name': 'Keyif',
#     'opening_hours:signed': 'no',
#     'outdoor_seating': 'yes',
#     'smoking': 'yes',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 280589004,
#    'lat': 52.5976055,
#    'lon': 13.2749705,
#    'tags': {'amenity': 'biergarten', 'name': 'Wirtshaus im Alten Fritz'}},
#   {'type': 'node',
#    'id': 282420247,
#    'lat': 52.5102582,
#    'lon': 13.4566212,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '36',
#     'addr:postcode': '10245',
#     'addr:street': 'Simon-Dach-Straße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'bar',
#     'contact:facebook': 'https://www.facebook.com/Cafe-Bar-Himmelreich-227297577458273/',
#     'contact:phone': '+49 30 29369292',
#     'contact:website': 'https://www.himmelreich-berlin.de',
#     'gay': 'yes',
#     'lgbtq': 'primary',
#     'name': 'Himmelreich',
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'yes',
#     'wheelchair:description': 'Behindertentoilette vorhanden, Räume barrierefrei erreichbar!'}},
#   {'type': 'node',
#    'id': 282420334,
#    'lat': 52.5106855,
#    'lon': 13.4568209,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '15',
#     'addr:postcode': '10245',
#     'addr:street': 'Krossener Straße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'pub',
#     'contact:phone': '+49 30 2911624',
#     'indoor_seating': 'yes',
#     'music_genre': 'metal',
#     'name': "Paule's Metal Eck",
#     'opening_hours': '19:00-05:00, Mo-Su 17:00-18:00+',
#     'outdoor_seating': 'yes',
#     'smoking': 'dedicated',
#     'website': 'https://www.paules-metal-eck.de',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 282425928,
#    'lat': 52.5143396,
#    'lon': 13.4596231,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '24',
#     'addr:postcode': '10247',
#     'addr:street': 'Niederbarnimstraße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'pub',
#     'brewery': 'yes',
#     'contact:email': 'tresen@salamas-bar.de',
#     'contact:phone': '+49 30 2965832',
#     'contact:website': 'http://www.salamas-bar.de',
#     'name': 'Salamas Bar',
#     'opening_hours': 'Mo 19:00+; Tu-Fr 16:00+; Sa,Su 13:00+',
#     'operator': 'Salama El-Khatib',
#     'outdoor_seating': 'sidewalk',
#     'smoking': 'yes',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 282428260,
#    'lat': 52.5158118,
#    'lon': 13.4591706,
#    'tags': {'amenity': 'bar',
#     'name': 'Radio',
#     'opening_hours': 'Tu-Th 17:00-01:00, Fr,Sa 17:00-01:00+; Su,Mo off',
#     'website': 'http://www.radiobar.berlin/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 282737297,
#    'lat': 52.5182491,
#    'lon': 13.4553049,
#    'tags': {'amenity': 'bar',
#     'contact:facebook': 'https://www.facebook.com/Lauschangriff.Berlin',
#     'name': 'Lauschangriff',
#     'opening_hours:signed': 'no'}},
#   {'type': 'node',
#    'id': 282742266,
#    'lat': 52.5179397,
#    'lon': 13.4656186,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '54',
#     'addr:postcode': '10247',
#     'addr:street': 'Bänschstraße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'pub',
#     'brewery': 'various',
#     'check_date:opening_hours': '2022-02-06',
#     'name': 'Lolly-Pub',
#     'note': 'Sports TV',
#     'opening_hours': 'Mo-Sa 15:00-24:00, Su 15:00-23:00',
#     'outdoor_seating': 'yes',
#     'phone': '+49-30-4267784',
#     'smoking': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 282815961,
#    'lat': 52.510094,
#    'lon': 13.4603525,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '24',
#     'addr:postcode': '10245',
#     'addr:street': 'Krossener Straße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'pub',
#     'contact:phone': '+49 30 2911937',
#     'drink:club-mate': 'served',
#     'indoor_seating': 'yes',
#     'name': 'Feuermelder',
#     'opening_hours': 'Mo-Su 18:00+',
#     'outdoor_seating': 'yes',
#     'smoking': 'dedicated',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Die Toilette ist nicht rollstuhlgerecht.'}},
#   {'type': 'node',
#    'id': 285066943,
#    'lat': 52.5111838,
#    'lon': 13.4613046,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '15',
#     'addr:postcode': '10245',
#     'addr:street': 'Gärtnerstraße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'pub',
#     'name': 'Zimt & Zunder',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 286428394,
#    'lat': 52.5372124,
#    'lon': 13.2022687,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '14a',
#     'addr:postcode': '13597',
#     'addr:street': 'Charlottenstraße',
#     'addr:suburb': 'Spandau',
#     'amenity': 'bar',
#     'name': 'Charlotte',
#     'phone': '+49 30 3331000',
#     'source': 'Geoportal Berlin / Hauskoordinaten',
#     'toilets:wheelchair': 'no',
#     'website': 'http://www.cbb-charlotte.de',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Keine Behindertentoilette'}},
#   {'type': 'node',
#    'id': 286428617,
#    'lat': 52.5378459,
#    'lon': 13.2031388,
#    'tags': {'amenity': 'pub', 'name': 'Spandauer Bock', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 288468824,
#    'lat': 52.4927208,
#    'lon': 13.4217007,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '34',
#     'addr:postcode': '10967',
#     'addr:street': 'Schönleinstraße',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'pub',
#     'contact:phone': '+49-30-6932015',
#     'name': 'Bei Schlawinchen',
#     'opening_hours': '24/7',
#     'start_date': '1979',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 288697592,
#    'lat': 52.500227,
#    'lon': 13.4602777,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '8',
#     'addr:postcode': '10245',
#     'addr:street': 'Bossestraße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'pub',
#     'contact:phone': '+49-30-3257403',
#     'name': 'Kiez-Kneipe II',
#     'opening_hours': 'Mo-Th 14:00-23:00+; Fr-Su 12:00-23:00+',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 291796493,
#    'lat': 52.5127422,
#    'lon': 13.458706,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '105',
#     'addr:postcode': '10245',
#     'addr:street': 'Boxhagener Straße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'bar',
#     'contact:phone': '+49 30 29046910',
#     'name': 'booze bar berlin',
#     'outdoor_seating': 'sidewalk',
#     'smoking': 'separated',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 293632127,
#    'lat': 52.5065269,
#    'lon': 13.3234849,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '9',
#     'addr:postcode': '10623',
#     'addr:street': 'Carmerstraße',
#     'addr:suburb': 'Charlottenburg',
#     'amenity': 'pub',
#     'contact:phone': '+49 30 3124952',
#     'contact:website': 'http://www.dicke-wirtin.de/',
#     'email': 'post@dicke-wirtin.de',
#     'name': 'Dicke Wirtin',
#     'opening_hours': 'Mo-Su 11:00+',
#     'operator': 'Uwe Drees',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 293644418,
#    'lat': 52.5059134,
#    'lon': 13.3283341,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '12A',
#     'addr:postcode': '10623',
#     'addr:street': 'Kantstraße',
#     'addr:suburb': 'Charlottenburg',
#     'amenity': 'nightclub',
#     'contact:email': 'info@quasimodo.de',
#     'contact:phone': '+49 30 31804560',
#     'contact:website': 'http://www.quasimodo.de/',
#     'name': 'Quasimodo',
#     'wheelchair': 'no',
#     'wikidata': 'Q2122439',
#     'wikipedia': 'de:Quasimodo (Musikclub)'}},
#   {'type': 'node',
#    'id': 297233488,
#    'lat': 52.5697896,
#    'lon': 13.3942046,
#    'tags': {'amenity': 'biergarten',
#     'name': 'Rosengarten',
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 297924895,
#    'lat': 52.4692776,
#    'lon': 13.4380596,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '131',
#     'addr:postcode': '12051',
#     'addr:street': 'Emser Straße',
#     'addr:suburb': 'Neukölln',
#     'amenity': 'pub',
#     'name': 'Laika',
#     'opening_hours': 'Mo-Sa 18:00-01:00, Su,PH 18:00-24:00',
#     'toilets:wheelchair': 'no',
#     'website': 'http://www.laika-neukoelln.de',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 300327588,
#    'lat': 52.5422827,
#    'lon': 13.2816533,
#    'tags': {'addr:housenumber': '274',
#     'addr:street': 'Heckerdamm',
#     'amenity': 'biergarten',
#     'contact:email': 'info@kulturbiergarten.de',
#     'contact:phone': '+49 1522 9796454',
#     'contact:website': 'https://kulturbiergarten.de/',
#     'name': 'Kulturbiergarten Jungfernheide',
#     'opening_hours': 'Mo-Sa 12:00-21:00; Su 11:00-21:00'}},
#   {'type': 'node',
#    'id': 303319472,
#    'lat': 52.4902359,
#    'lon': 13.426145,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '62',
#     'addr:postcode': '12047',
#     'addr:street': 'Hobrechtstraße',
#     'addr:suburb': 'Neukölln',
#     'amenity': 'pub',
#     'name': 'Lenau-Stuben',
#     'phone': '+49-30-6934854',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 303319474,
#    'lat': 52.4905139,
#    'lon': 13.4261189,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '61',
#     'addr:postcode': '12047',
#     'addr:street': 'Hobrechtstraße',
#     'addr:suburb': 'Neukölln',
#     'amenity': 'pub',
#     'name': 'Mama',
#     'smoking': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 304045906,
#    'lat': 52.5136836,
#    'lon': 13.4660501,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '9',
#     'addr:postcode': '10247',
#     'addr:street': 'Kinzigstraße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'pub',
#     'internet_access': 'wlan',
#     'internet_access:fee': 'no',
#     'name': 'loge.',
#     'opening_hours': '18:00+, Th-Sa 19:00-18:00+',
#     'smoking': 'yes',
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 304050485,
#    'lat': 52.5136974,
#    'lon': 13.4666469,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housename': 'K9',
#     'addr:housenumber': '9',
#     'addr:postcode': '10247',
#     'addr:street': 'Kinzigstraße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'pub',
#     'contact:website': 'http://www.kinzig9.de',
#     'internet_access': 'wlan',
#     'internet_access:fee': 'no',
#     'name': 'K9',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 304183823,
#    'lat': 52.5780418,
#    'lon': 13.3331997,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '70',
#     'addr:postcode': '13403',
#     'addr:street': 'Ollenhauerstraße',
#     'addr:suburb': 'Reinickendorf',
#     'amenity': 'pub',
#     'name': "Meiner's",
#     'phone': '+49-30-41783145',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 304367339,
#    'lat': 52.5287997,
#    'lon': 13.281752,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '92',
#     'addr:postcode': '14050',
#     'addr:street': 'Fürstenbrunner Weg',
#     'addr:suburb': 'Westend',
#     'amenity': 'pub',
#     'name': 'Gaststätte Tunnel-Eck'}},
#   {'type': 'node',
#    'id': 306648908,
#    'lat': 52.5179389,
#    'lon': 13.3179556,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '15',
#     'addr:postcode': '10587',
#     'addr:street': 'Cauerstraße',
#     'addr:suburb': 'Charlottenburg',
#     'amenity': 'pub',
#     'mapillary': 'XCsn3lgcJyCVeKd14wZr1A',
#     'name': 'Luna',
#     'note': 'hier sollte "am 1.12.2020 eine gutbürgerliche Gaststätte" eröffnen, s mapillary',
#     'old_name': 'Bei Mutt',
#     'opening_hours': 'Mo-Th 12:00-24:00, Fr,Sa 12:00-02:00, Su 12:00-22:00'}},
#   {'type': 'node',
#    'id': 306915565,
#    'lat': 52.5476473,
#    'lon': 13.4887012,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '20',
#     'addr:postcode': '13053',
#     'addr:street': 'Waldowstraße',
#     'addr:suburb': 'Alt-Hohenschönhausen',
#     'amenity': 'pub',
#     'contact:email': 'kontakt@berlin-wasserturm.de',
#     'contact:phone': '+49 178 5389745',
#     'contact:website': 'http://www.berlin-wasserturm.de/',
#     'name': 'Bar im Wasserturm'}},
#   {'type': 'node',
#    'id': 307467687,
#    'lat': 52.5251899,
#    'lon': 13.4519782,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '24',
#     'addr:postcode': '10249',
#     'addr:street': 'Kochhannstraße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'pub',
#     'contact:phone': '+49-30-4260066',
#     'cuisine': 'german',
#     'name': 'Budike',
#     'opening_hours': 'Mo-Fr 12:00-23:00; Sa-Su 16:00-22:00',
#     'opening_hours:covid19': 'off',
#     'takeaway:covid19': 'Mo-Su 14:00-20:00',
#     'wheelchair': 'no',
#     'wheelchair:description': 'Im Sommer kann auch draußen gegessen werden.'}},
#   {'type': 'node',
#    'id': 308525842,
#    'lat': 52.5511652,
#    'lon': 13.4043646,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '23',
#     'addr:postcode': '10439',
#     'addr:street': 'Schivelbeiner Straße',
#     'addr:suburb': 'Prenzlauer Berg',
#     'amenity': 'pub',
#     'contact:phone': '+49 30 12029219',
#     'name': 'Blaumilchkanal',
#     'opening_hours': 'Mo-Su 18:00-01:00',
#     'smoking': 'no',
#     'source:opening_hours': 'survey',
#     'website': 'http://www.blaumilchkanal.com',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 309054593,
#    'lat': 52.5202205,
#    'lon': 13.3443367,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '7',
#     'addr:postcode': '10557',
#     'addr:street': 'Flensburger Straße',
#     'addr:suburb': 'Hansaviertel',
#     'amenity': 'pub',
#     'contact:email': 'info@thelir.de',
#     'contact:phone': '+49 30 3928502',
#     'contact:website': 'http://www.thelir.de/',
#     'name': 'The Lir',
#     'opening_hours': 'Mo-Su 17:00-02:00',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 309902514,
#    'lat': 52.5252025,
#    'lon': 13.4018544,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '6',
#     'addr:postcode': '10178',
#     'addr:street': 'Sophienstraße',
#     'addr:suburb': 'Mitte',
#     'amenity': 'bar',
#     'contact:website': 'http://www.billardkoeh.de',
#     'name': 'Billardsalon Köh',
#     'opening_hours': 'Mo-Sa 17:00+; Su 16:00+',
#     'sport': 'billiards',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 312253713,
#    'lat': 52.5292596,
#    'lon': 13.408163,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '65',
#     'addr:postcode': '10119',
#     'addr:street': 'Torstraße',
#     'addr:suburb': 'Prenzlauer Berg',
#     'amenity': 'pub',
#     'contact:email': 'prassnik@mangelwirtschaft.de',
#     'contact:website': 'http://www.mangelwirtschaft.de/',
#     'name': 'Prassnik',
#     'official_name': 'Gaststätte W. Prassnik',
#     'opening_hours': '18:00+',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 312697960,
#    'lat': 52.4945949,
#    'lon': 13.400091,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '61',
#     'addr:postcode': '10961',
#     'addr:street': 'Blücherstraße',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'pub',
#     'contact:phone': '+49-30-6944782',
#     'name': 'Cafe Logo',
#     'opening_hours': '24/7',
#     'smoking': 'yes',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 313281470,
#    'lat': 52.5889737,
#    'lon': 13.2879509,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '1',
#     'addr:postcode': '13507',
#     'addr:street': 'Grußdorfstraße',
#     'addr:suburb': 'Tegel',
#     'amenity': 'pub',
#     'name': 'Zum Kegel',
#     'url': 'http://www.zumkegel.de/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 315366750,
#    'lat': 52.4916417,
#    'lon': 13.4197294,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '36',
#     'addr:postcode': '10967',
#     'addr:street': 'Dieffenbachstraße',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'pub',
#     'name': 'Pony-Saloon',
#     'opening_hours': '17:00-03:00',
#     'smoking': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 315757114,
#    'lat': 52.5240722,
#    'lon': 13.3323282,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '72',
#     'addr:postcode': '10555',
#     'addr:street': 'Alt-Moabit',
#     'addr:suburb': 'Moabit',
#     'amenity': 'bar',
#     'name': 'Empire Lounge Shisha-Bar',
#     'note': 'Cocktail Shisha Lounge',
#     'opening_hours:signed': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 316657525,
#    'lat': 52.527485,
#    'lon': 13.4801013,
#    'tags': {'amenity': 'pub',
#     'cuisine': 'kebab',
#     'name': "Mac's Deluxe",
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 317152543,
#    'lat': 52.5260175,
#    'lon': 13.4518343,
#    'tags': {'amenity': 'pub',
#     'fixme': 'address;verify name',
#     'name': 'Eberty Treff',
#     'opening_hours:signed': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 318704396,
#    'lat': 52.5219305,
#    'lon': 13.4529113,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '14',
#     'addr:postcode': '10249',
#     'addr:street': 'Matternstraße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'pub',
#     'contact:email': 'thomas@drittes-ohr.com',
#     'contact:phone': '+49-30-4275798',
#     'contact:website': 'http://www.drittes-ohr.com/',
#     'name': 'Drittes Ohr',
#     'opening_hours': 'Mo-Fr 18:00-03:00+; Sa,Su,PH 20:00-03:00+',
#     'phone': '+493050173385',
#     'website': 'http://www.drittes-ohr.com/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 318810769,
#    'lat': 52.5493859,
#    'lon': 13.4164647,
#    'tags': {'amenity': 'bar',
#     'name': 'Deck 5',
#     'note': 'sand on the roof',
#     'website': 'http://www.freiluftrebellen.de/en/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 320217866,
#    'lat': 52.534462,
#    'lon': 13.404733,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '39',
#     'addr:postcode': '10119',
#     'addr:street': 'Zionskirchstraße',
#     'addr:suburb': 'Mitte',
#     'amenity': 'bar',
#     'name': 'macke prinz',
#     'opening_hours': 'Mo-Su 13:00-03:00',
#     'outdoor_seating': 'yes',
#     'smoking': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 322178039,
#    'lat': 52.5263978,
#    'lon': 13.398569,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '37',
#     'addr:postcode': '10115',
#     'addr:street': 'Große Hamburger Straße',
#     'addr:suburb': 'Mitte',
#     'amenity': 'pub',
#     'contact:email': 'info@sophieneck-berlin.de',
#     'contact:facebook': 'Sophieneck',
#     'contact:fax': '+49 30 28599860',
#     'contact:phone': '+49 30 2834065',
#     'contact:website': 'https://www.sophieneck-berlin.de',
#     'cuisine': 'regional',
#     'food': 'yes',
#     'name': 'Sophieneck',
#     'opening_hours': 'PH,Mo-Su 12:00-02:00',
#     'operator': 'DUWENO Gaststätten- und Hotelbetriebs GmbH',
#     'outdoor_seating': 'yes',
#     'smoking': 'outside',
#     'source': 'survey',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 322822423,
#    'lat': 52.5288311,
#    'lon': 13.4488396,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '11',
#     'addr:postcode': '10407',
#     'addr:street': 'Cotheniusstraße',
#     'addr:suburb': 'Prenzlauer Berg',
#     'amenity': 'pub',
#     'name': 'Zum Leibarzt',
#     'opening_hours:signed': 'no',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 325585700,
#    'lat': 52.5254904,
#    'lon': 13.4474575,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '44',
#     'addr:postcode': '10249',
#     'addr:street': 'Petersburger Straße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'pub',
#     'name': 'Zum Friedrichshainer',
#     'phone': '+49-30-4292817',
#     'smoking': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 329605839,
#    'lat': 52.4143006,
#    'lon': 13.3637108,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '136',
#     'addr:postcode': '12277',
#     'addr:street': 'Marienfelder Allee',
#     'addr:suburb': 'Marienfelde',
#     'amenity': 'pub',
#     'name': "Uli's Bar"}},
#   {'type': 'node',
#    'id': 330257797,
#    'lat': 52.5359066,
#    'lon': 13.4050034,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '5',
#     'addr:postcode': '10435',
#     'addr:street': 'Griebenowstraße',
#     'addr:suburb': 'Mitte',
#     'amenity': 'pub',
#     'contact:facebook': 'https://www.facebook.com/weinereiperlin/',
#     'contact:website': 'https://www.weinerei.com/#!/location-perlin',
#     'cuisine': 'spanish',
#     'drink:wine': 'served',
#     'food': 'yes',
#     'internet_access': 'no',
#     'name': 'Perlin',
#     'opening_hours': 'We-Su 18:00+',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 330259891,
#    'lat': 52.533631,
#    'lon': 13.402655,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '57',
#     'addr:postcode': '10119',
#     'addr:street': 'Fehrbelliner Straße',
#     'addr:suburb': 'Mitte',
#     'amenity': 'pub',
#     'contact:phone': '+49-30-4406983',
#     'contact:website': 'http://weinerei.com/forum/',
#     'food': 'yes',
#     'name': 'Weinerei Forum',
#     'opening_hours': 'Mo-Su 10:00-24:00',
#     'outdoor_seating': 'yes',
#     'smoking': 'separated',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 331397676,
#    'lat': 52.5086027,
#    'lon': 13.4610994,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '43',
#     'addr:postcode': '10245',
#     'addr:street': 'Wühlischstraße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'bar',
#     'name': 'Süß war gestern',
#     'opening_hours:signed': 'no',
#     'smoking': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 332554291,
#    'lat': 52.5215879,
#    'lon': 13.38609,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '6',
#     'addr:postcode': '10117',
#     'addr:street': 'Schiffbauerdamm',
#     'addr:suburb': 'Mitte',
#     'amenity': 'bar',
#     'contact:phone': '+49 30 27582305',
#     'name': 'Vincent Piano Bar',
#     'website': 'http://vincent-bar.de/hauptseite/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 332625324,
#    'lat': 52.5223201,
#    'lon': 13.3838875,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '18',
#     'addr:postcode': '10117',
#     'addr:street': 'Marienstraße',
#     'addr:suburb': 'Mitte',
#     'amenity': 'pub',
#     'contact:phone': '+49 30 27596909',
#     'contact:website': 'http://www.boesebubenbar.de',
#     'cuisine': 'regional',
#     'food': 'yes',
#     'name': 'Böse Buben Bar',
#     'opening_hours': '10:00+',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 333322726,
#    'lat': 52.476861,
#    'lon': 13.4212617,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '7',
#     'addr:postcode': '12049',
#     'addr:street': 'Herrfurthplatz',
#     'addr:suburb': 'Neukölln',
#     'amenity': 'pub',
#     'name': 'Daffke',
#     'smoking': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 333730237,
#    'lat': 52.5338484,
#    'lon': 13.4035776,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '34',
#     'addr:postcode': '10119',
#     'addr:street': 'Zionskirchstraße',
#     'addr:suburb': 'Mitte',
#     'amenity': 'pub',
#     'cuisine': 'international',
#     'name': 'Ick koof mir Dave Lombardo, wenn ick reich bin',
#     'smoking': 'yes',
#     'url': 'http://www.lombardo-bar.de/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 333733050,
#    'lat': 52.5329814,
#    'lon': 13.3999802,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '26',
#     'addr:postcode': '10119',
#     'addr:street': 'Veteranenstraße',
#     'addr:suburb': 'Mitte',
#     'amenity': 'pub',
#     'contact:email': 'info@fcmagnetbar.de',
#     'name': 'FC Magnet Bar',
#     'operator': 'Andreas Sürken',
#     'smoking': 'separated',
#     'url': 'http://www.fcmagnetbar.de/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 336140140,
#    'lat': 52.5325107,
#    'lon': 13.4061676,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '76',
#     'addr:postcode': '10119',
#     'addr:street': 'Choriner Straße',
#     'addr:suburb': 'Mitte',
#     'amenity': 'pub',
#     'contact:phone': '+49304496939',
#     'contact:website': 'http://www.schwarzepumpe-berlin.de/',
#     'name': 'Schwarze Pumpe',
#     'opening_hours': 'Mo-Fr 11:00-01:00, Sa,Su 17:00-01:00',
#     'smoking': 'no',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 336140143,
#    'lat': 52.5330606,
#    'lon': 13.4072137,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '12',
#     'addr:postcode': '10119',
#     'addr:street': 'Choriner Straße',
#     'addr:suburb': 'Prenzlauer Berg',
#     'amenity': 'pub',
#     'contact:phone': '+49-30-81897804',
#     'contact:website': 'http://www.ruf-mich-nie-wieder-an.de/cafe.html',
#     'name': 'Lass uns Freunde bleiben',
#     'smoking': 'dedicated',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 336384880,
#    'lat': 52.5213573,
#    'lon': 13.3856815,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '8',
#     'addr:postcode': '10117',
#     'addr:street': 'Schiffbauerdamm',
#     'addr:suburb': 'Mitte',
#     'amenity': 'pub',
#     'contact:phone': '+49 30 30872293',
#     'email': 'info@die-berliner-republik.de',
#     'fax': '+49 30 30872295',
#     'name': 'Die Berliner Republik',
#     'website': 'http://www.die-berliner-republik.de'}},
#   {'type': 'node',
#    'id': 339323154,
#    'lat': 52.5142681,
#    'lon': 13.4595488,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '23',
#     'addr:postcode': '10247',
#     'addr:street': 'Niederbarnimstraße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'pub',
#     'contact:email': 'tresen@sohnemann-bar.de',
#     'contact:phone': '+49-163 5980195',
#     'contact:website': 'https://sohnemann-bar.de/',
#     'name': 'Sohnemann',
#     'opening_hours': 'Tu-Th 18:00-01:00; Fr-Sa 18:00-03:00',
#     'operator': 'Hausstein & Schultz GbR',
#     'smoking': 'separated',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 339323158,
#    'lat': 52.5136056,
#    'lon': 13.4604415,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '22',
#     'addr:postcode': '10247',
#     'addr:street': 'Kreutzigerstraße',
#     'addr:suburb': 'Friedrichshain',
#     'amenity': 'pub',
#     'contact:phone': '+49-30-67820297',
#     'drink:club-mate': 'yes',
#     'name': 'Pk Bar',
# ...
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'yes',
#     'wheelchair:note': 'alles wie es sein soll! everything how it should be!'}},
#   {'type': 'node',
#    'id': 2390734924,
#    'lat': 52.550607,
#    'lon': 13.363522,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '10a',
#     'addr:postcode': '13347',
#     'addr:street': 'Hochstädter Straße',
#     'addr:suburb': 'Wedding',
#     'amenity': 'pub',
#     'contact:email': 'cafecralle@riseup.net',
#     'contact:phone': '+49 30 4553001',
#     'identity': 'solidarity_economy',
#     'mode_of_organisation:self_managed': 'yes',
#     'name': 'Café Cralle',
#     'opening_hours': 'Mo-Su 19:00-24:00',
#     'smoking': 'separated',
#     'source': 'Solikon 2015',
#     'toilets:wheelchair': 'no',
#     'website': 'https://cafecralle.wordpress.com/',
#     'wheelchair': 'no',
#     'wheelchair:description': '2 Stufen'}},
#   {'type': 'node',
#    'id': 2397780250,
#    'lat': 52.6256811,
#    'lon': 13.2292382,
#    'tags': {'amenity': 'pub', 'name': 'Heiligensee Schänke'}},
#   {'type': 'node',
#    'id': 2420872160,
#    'lat': 52.5320467,
#    'lon': 13.3415576,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '46',
#     'addr:postcode': '10551',
#     'addr:street': 'Birkenstraße',
#     'addr:suburb': 'Moabit',
#     'amenity': 'bar',
#     'contact:email': 'stefan.johannes.tirree@gmail.com',
#     'contact:facebook': 'https://www.facebook.com/Tirree.Berlin/timeline?ref=page_internal',
#     'contact:phone': '+49 176 70713839',
#     'contact:website': 'https://tirree.eatbu.com/',
#     'cuisine': 'breakfast',
#     'indoor_seating': 'yes',
#     'internet_access': 'wlan',
#     'internet_access:fee': 'no',
#     'internet_access:operator': 'airfy',
#     'internet_access:ssid': 'airfy free WiFi',
#     'name': 'Tirrée',
#     'note': 'Leckeres und aussergewöhnliches Frühstück.',
#     'opening_hours': 'Mo-Sa 09:00-02:00, Su 09:00-24:00',
#     'operator': 'Stefan Tirree',
#     'outdoor_seating': 'yes',
#     'smoking': 'separated',
#     'takeaway': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2420872339,
#    'lat': 52.5319725,
#    'lon': 13.3283139,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '49',
#     'addr:postcode': '10553',
#     'addr:street': 'Beusselstraße',
#     'addr:suburb': 'Moabit',
#     'amenity': 'casino',
#     'name': 'Casino 777',
#     'name:fa': 'کازینو ۷۷۷',
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2423932912,
#    'lat': 52.5015069,
#    'lon': 13.419281,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '90',
#     'addr:postcode': '10997',
#     'addr:street': 'Adalbertstraße',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'bar',
#     'name': 'Rote Rose',
#     'opening_hours': '24/7',
#     'smoking': 'yes',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2424288635,
#    'lat': 52.4446007,
#    'lon': 13.5777014,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '3',
#     'addr:postcode': '12555',
#     'addr:street': 'Kietzer Straße',
#     'addr:suburb': 'Köpenick',
#     'amenity': 'bar',
#     'cuisine': 'japanese',
#     'name': 'Kumami',
#     'opening_hours': 'Tu-Sa 18:00-22:00',
#     'website': 'https://www.kumamiberlin.com/'}},
#   {'type': 'node',
#    'id': 2426391493,
#    'lat': 52.5418185,
#    'lon': 13.3335979,
#    'tags': {'alt_name': 'Bootshaus am See',
#     'amenity': 'pub',
#     'name': 'Zur Fischerpinte'}},
#   {'type': 'node',
#    'id': 2427442170,
#    'lat': 52.53017,
#    'lon': 13.3401888,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '15',
#     'addr:postcode': '10551',
#     'addr:street': 'Bredowstraße',
#     'addr:suburb': 'Moabit',
#     'air_conditioning': 'no',
#     'amenity': 'pub',
#     'check_date:opening_hours': '2022-04-12',
#     'contact:phone': '+49 30 395 63 84',
#     'contact:website': 'http://www.zum-stammtisch.de/',
#     'cuisine': 'regional',
#     'diet:vegetarian': 'yes',
#     'name': 'Zum Stammtisch',
#     'opening_hours:signed': 'no',
#     'outdoor_seating': 'yes',
#     'smoking': 'outside',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2432755484,
#    'lat': 52.5022042,
#    'lon': 13.4328535,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '24',
#     'addr:postcode': '10997',
#     'addr:street': 'Wrangelstraße',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'bar',
#     'contact:phone': '+49 (0) 30 23135569',
#     'name': 'Schwarze Traube',
#     'smoking': 'yes'}},
#   {'type': 'node',
#    'id': 2435092394,
#    'lat': 52.4643506,
#    'lon': 13.4333842,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '146',
#     'addr:postcode': '12051',
#     'addr:street': 'Hermannstraße',
#     'addr:suburb': 'Neukölln',
#     'alt_name': 'Hole Berlin',
#     'amenity': 'nightclub',
#     'name': 'Hole 44',
#     'website': 'https://hole-berlin.de/'}},
#   {'type': 'node',
#    'id': 2439759291,
#    'lat': 52.5094377,
#    'lon': 13.2774619,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '80',
#     'addr:postcode': '14057',
#     'addr:street': 'Kaiserdamm',
#     'addr:suburb': 'Westend',
#     'amenity': 'pub',
#     'name': 'The Moonlight'}},
#   {'type': 'node',
#    'id': 2442886682,
#    'lat': 52.4904849,
#    'lon': 13.3227685,
#    'tags': {'amenity': 'pub', 'name': 'Uh-Länder'}},
#   {'type': 'node',
#    'id': 2451154239,
#    'lat': 52.4863418,
#    'lon': 13.3636771,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '1',
#     'addr:postcode': '10829',
#     'addr:street': 'Naumannstraße',
#     'amenity': 'pub',
#     'name': 'Jonas',
#     'note': 'Billiards & Darts',
#     'opening_hours': 'Mo-Su 11:00-18:00+',
#     'phone': '+49-30-7844603',
#     'toilets:wheelchair': 'no',
#     'website': 'https://www.jonas-berlin.de/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2455728690,
#    'lat': 52.480489,
#    'lon': 13.3485076,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '9',
#     'addr:postcode': '10827',
#     'addr:street': 'Fritz-Reuter-Straße',
#     'addr:suburb': 'Schöneberg',
#     'amenity': 'pub',
#     'contact:facebook': 'https://www.facebook.com/erxlounge/',
#     'name': 'Erx Lounge',
#     'operator': 'Erkan Dede'}},
#   {'type': 'node',
#    'id': 2464442840,
#    'lat': 52.5004839,
#    'lon': 13.4225958,
#    'tags': {'amenity': 'pub', 'name': 'Bateau Ivre', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2471000025,
#    'lat': 52.5391578,
#    'lon': 13.2059442,
#    'tags': {'alt_name': "Martha's Bar",
#     'amenity': 'bar',
#     'name': 'Mephisto Bar',
#     'wheelchair': 'yes',
#     'wifi': 'no'}},
#   {'type': 'node',
#    'id': 2472046777,
#    'lat': 52.5510264,
#    'lon': 13.509957,
#    'tags': {'amenity': 'bar', 'name': 'Q1 Cafe Lounge', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2473561758,
#    'lat': 52.5008761,
#    'lon': 13.4302896,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '16',
#     'addr:postcode': '10997',
#     'addr:street': 'Lausitzer Platz',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'bar',
#     'drink:wine': 'yes',
#     'name': 'Saveur Champagne'}},
#   {'type': 'node',
#    'id': 2476384360,
#    'lat': 52.4747729,
#    'lon': 13.4223976,
#    'tags': {'amenity': 'pub', 'name': "Dart's e.V."}},
#   {'type': 'node',
#    'id': 2476417006,
#    'lat': 52.4866674,
#    'lon': 13.3228483,
#    'tags': {'amenity': 'pub', 'name': 'Uhland Eck', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2482984713,
#    'lat': 52.5443687,
#    'lon': 13.3597319,
#    'tags': {'amenity': 'bar', 'name': 'Cafe Trifft'}},
#   {'type': 'node',
#    'id': 2482984716,
#    'lat': 52.5434766,
#    'lon': 13.3582056,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '65',
#     'addr:postcode': '13353',
#     'addr:street': 'Triftstraße',
#     'addr:suburb': 'Wedding',
#     'amenity': 'bar',
#     'check_date:opening_hours': '2022-04-10',
#     'name': 'Bar 65',
#     'opening_hours:signed': 'no'}},
#   {'type': 'node',
#    'id': 2483768468,
#    'lat': 52.5448883,
#    'lon': 13.3613469,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '157',
#     'addr:postcode': '13353',
#     'addr:street': 'Müllerstraße',
#     'addr:suburb': 'Wedding',
#     'amenity': 'bar',
#     'contact:website': 'http://barsolut.de/',
#     'indoor_seating': 'yes',
#     'name': 'Bar Solut',
#     'opening_hours': 'Mo-Su 11:00-23:00',
#     'opening_hours:signed': 'no',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2495554363,
#    'lat': 52.4880065,
#    'lon': 13.3868088,
#    'tags': {'addr:city': 'Berlin',
#     'addr:housenumber': '8',
#     'addr:postcode': '10965',
#     'addr:street': 'Am Tempelhofer Berg',
#     'amenity': 'pub',
#     'name': 'Arcanoa',
#     'opening_hours': 'Mo,We-Sa 20:00-03:00',
#     'website': 'http://www.arcanoa.de/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2495554364,
#    'lat': 52.4894745,
#    'lon': 13.3867705,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '77',
#     'addr:postcode': '10965',
#     'addr:street': 'Mehringdamm',
#     'amenity': 'bar',
#     'name': 'Barbie Bar',
#     'phone': '+49 30 69568610',
#     'smoking': 'yes',
#     'website': 'http://www.barbiebar.de',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2495554382,
#    'lat': 52.4871284,
#    'lon': 13.3864809,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '107',
#     'addr:postcode': '10965',
#     'addr:street': 'Mehringdamm',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'bar',
#     'name': 'Mandingo-Diskothek',
#     'source': 'Geoportal Berlin / Hauskoordinaten',
#     'website': 'http://www.mandingoclub.de/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2495554575,
#    'lat': 52.4886356,
#    'lon': 13.3918258,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '15',
#     'addr:postcode': '10965',
#     'addr:street': 'Arndtstraße',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'pub',
#     'name': 'Heidelberger Krug',
#     'opening_hours': 'Mo-Sa 16:00-02:00, Su 16:00-01:00',
#     'smoking': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2496059352,
#    'lat': 52.4752829,
#    'lon': 13.3402711,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '89',
#     'addr:postcode': '12159',
#     'addr:street': 'Hauptstraße',
#     'addr:suburb': 'Schöneberg',
#     'amenity': 'pub',
#     'check_date:opening_hours': '2022-02-23',
#     'name': 'Sponholz',
#     'opening_hours': 'Mo-Su 15:00-23:00',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2496651175,
#    'lat': 52.4898238,
#    'lon': 13.3899477,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '100',
#     'addr:postcode': '10961',
#     'addr:street': 'Bergmannstraße',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'pub',
#     'name': 'Atlantic',
#     'phone': '+4930 6919292',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2496651176,
#    'lat': 52.4900059,
#    'lon': 13.3889535,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '104',
#     'addr:postcode': '10961',
#     'addr:street': 'Bergmannstraße',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'bar',
#     'name': "Sam's Bar",
#     'opening_hours': 'Su-Th 17:30-01:00, Fr,Sa 17:30-04:00'}},
#   {'type': 'node',
#    'id': 2496651187,
#    'lat': 52.4903858,
#    'lon': 13.3870441,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '67',
#     'addr:postcode': '10961',
#     'addr:street': 'Mehringdamm',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'pub',
#     'email': 'info@destille-kreuzberg.de',
#     'name': 'Destille',
#     'opening_hours': 'Mo-Sa 15:00-05:00; Su 15:00-02:00',
#     'operator': 'Uwe Drees',
#     'phone': '+49-30-6925124',
#     'smoking': 'yes',
#     'url': 'https://destille-kreuzberg.de',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2496860542,
#    'lat': 52.5397141,
#    'lon': 13.4141454,
#    'tags': {'amenity': 'bar',
#     'billiards': '15',
#     'name': 'Pool & Cigars',
#     'opening_hours': 'Mo-Fr 17:00+; Sa,Su 13:00+',
#     'operator': 'Immo Schwedt;Pool & Cigars GmbH',
#     'outdoor_seating': 'no',
#     'phone': '+49 30 4050 0436',
#     'smoking': 'isolated',
#     'sport': 'billiards',
#     'website': 'http://www.poolandcigars.de/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2497904104,
#    'lat': 52.5002762,
#    'lon': 13.4397185,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '68',
#     'addr:postcode': '10997',
#     'addr:street': 'Skalitzer Straße',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'bar',
#     'name': 'CoBa Bar'}},
#   {'type': 'node',
#    'id': 2512986102,
#    'lat': 52.5298844,
#    'lon': 13.4245765,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '9',
#     'addr:postcode': '10405',
#     'addr:street': 'Heinrich-Roller-Straße',
#     'addr:suburb': 'Prenzlauer Berg',
#     'amenity': 'bar',
#     'contact:website': 'http://www.vineriacarvalho.de/',
#     'name': 'Vineria Carvalho',
#     'wheelchair': 'limited',
#     'wheelchair:description': '2 Stufen aber Klingel für Rollstuhlfahrer. Freundliche Bedienung kommt raus.'}},
#   {'type': 'node',
#    'id': 2519993920,
#    'lat': 52.5137959,
#    'lon': 13.291197,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '43',
#     'addr:postcode': '14059',
#     'addr:street': 'Danckelmannstraße',
#     'addr:suburb': 'Charlottenburg',
#     'amenity': 'pub',
#     'contact:phone': '+49 30 47399469',
#     'contact:website': 'http://www.langer-wirt.de',
#     'name': 'Langer Wirt',
#     'opening_hours': 'Mo-Th 18:00-01:00, Fr 18:00-02:00, Sa 18:00-03:00, Su 18:00-00:00',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2520049268,
#    'lat': 52.5176799,
#    'lon': 13.2937627,
#    'tags': {'amenity': 'pub',
#     'name': 'Glaube Liebe Hoffnung',
#     'opening_hours': 'Tu-Su 17:00-22:00+',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2520071252,
#    'lat': 52.502485,
#    'lon': 13.3009001,
#    'tags': {'amenity': 'pub', 'name': 'Schelle', 'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2524502813,
#    'lat': 52.5332865,
#    'lon': 13.4245632,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '61',
#     'addr:postcode': '10405',
#     'addr:street': 'Winsstraße',
#     'addr:suburb': 'Prenzlauer Berg',
#     'amenity': 'pub',
#     'atm': 'no',
#     'contact:website': 'http://www.tomsky-bar.de/',
#     'cuisine': 'american',
#     'food': 'yes',
#     'name': 'Tomsky',
#     'opening_hours': 'Mo-Su 18:00+',
#     'smoking': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2529284228,
#    'lat': 52.5478615,
#    'lon': 13.3493543,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '3',
#     'addr:postcode': '13353',
#     'addr:street': 'Antwerpener Straße',
#     'addr:suburb': 'Wedding',
#     'amenity': 'pub',
#     'microbrewery': 'yes',
#     'name': 'Vagabund Brauerei Taproom',
#     'opening_hours': 'Su-Th 17:00-24:00; Fr-Sa 17:00-02:00',
#     'payment:bitcoin': 'yes',
#     'smoking': 'no',
#     'toilets:wheelchair': 'no',
#     'website': 'https://www.vagabundbrauerei.com/',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Ask for entrance ramp, if needed. Toilet entrance is very narrow.'}},
#   {'type': 'node',
#    'id': 2532870724,
#    'lat': 52.5076388,
#    'lon': 13.3091999,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '41',
#     'addr:postcode': '10627',
#     'addr:street': 'Krumme Straße',
#     'addr:suburb': 'Charlottenburg',
#     'amenity': 'bar',
#     'indoor_seating': 'yes',
#     'name': 'Forty One',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'no'}},
#   ...]}
